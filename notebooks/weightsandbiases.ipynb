# %%
import wandb

# start a new wandb run to track this script
wandb.init(
    # set the wandb project where this run will be logged
    project="NN MATseq",
    notes="Small NN for MATseq",
    tags=["classifier", "MATseq"],
)

wandb.finish()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Appending key for api.wandb.ai to your netrc file: /home/t.afanasyeva/.netrc
# Tracking run with wandb version 0.15.8
# Run data is saved locally in <code>/home/t.afanasyeva/wandb/run-20230825_150210-kji1zfv8</code>
# Syncing run <strong><a href='https://wandb.ai/afanasyeva-team/my-awesome-project/runs/kji1zfv8' target="_blank">serene-microwave-1</a></strong> to <a href='https://wandb.ai/afanasyeva-team/my-awesome-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
# ...

# %%
# track hyperparameters and run metadata

wandb.config = {
    "hidden_layer_sizes": [5],
    "epoches": 10,
}
