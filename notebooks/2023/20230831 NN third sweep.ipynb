# %% [markdown]
# # Neural network for classification of contaminants with MAT

# %% [markdown]
# ## 1. Formulate/outline the problem: classification

# %% [markdown]
# Simple neural network for classification of the contaminants using MAT transcriptomes

# %%
import os

# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import wandb
import tensorflow as tf
from tensorflow import keras
# Out:
# 2023-11-06 15:54:58.454693: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-06 15:54:58.494452: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-06 15:54:58.494479: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-06 15:54:58.494508: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-06 15:54:58.502307: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
file_name = "gene_counts_NN_training.csv"

# %%
data = pd.read_csv(file_name)

# %% [markdown]
# ## 2. Identify inputs and outputs

# %%
data["sample"].value_counts()
# Out:
# sample
# R848       5
# CRX-527    5
# CL-307     5
# Pam3       5
# LPS        5
# PGN        5
# IMDM       5
# Fla-PA     3
# LTA        3
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Prepare data

# %%
data_features = data.drop(columns=["sample"])
target = data["sample"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    data_features, target, test_size=0.2, random_state=0, shuffle=True, stratify=target
)

# %%
y_train.value_counts(), y_test.value_counts()
# Out:
# (sample
#  Pam3       4
#  R848       4
#  IMDM       4
#  PGN        4
#  LPS        4
#  CRX-527    4
#  CL-307     4
#  Fla-PA     2
#  LTA        2
#  Name: count, dtype: int64,
#  sample
#  Pam3       1
#  R848       1
#  Fla-PA     1
#  CRX-527    1
#  LPS        1
#  LTA        1
#  IMDM       1
#  PGN        1
#  CL-307     1
#  Name: count, dtype: int64)

# %%
def to_normalize_DESeq2_style(data):
    # Ensure all values are non-negative
    data = data.applymap(lambda x: max(x, 0))

    # Take the log
    log_data = np.log1p(data)

    # Calculate the pseudo-reference sample for each gene
    log_data["pseudo_reference"] = log_data.mean(axis=1)

    # Filter out genes with -Inf as their average
    filtered_log_data = log_data[log_data["pseudo_reference"] != float("-inf")]

    # Subtract the gene pseudo-references from log counts
    ratio_data = filtered_log_data.iloc[:, :-1].sub(
        filtered_log_data["pseudo_reference"], axis=0
    )

    # Find the median of the ratios for each sample
    sample_medians = ratio_data.median(axis=0)

    # Convert medians to scaling factors
    scaling_factors = np.exp(sample_medians)

    # Divide the original counts by the scaling factors
    manually_normalized = data.div(scaling_factors)

    return manually_normalized


X_train = to_normalize_DESeq2_style(X_train)

X_test = to_normalize_DESeq2_style(X_test)
# Out:
# /tmp/ipykernel_3264398/2095961712.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data = data.applymap(lambda x: max(x, 0))
# /tmp/ipykernel_3264398/2095961712.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data = data.applymap(lambda x: max(x, 0))

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(y_train)
encoded_labels = le.transform(y_train)
le_name_mapping = dict(zip(le.classes_, encoded_labels))

# %%
le_name_mapping
# Out:
# {'CL-307': 7,
#  'CRX-527': 8,
#  'Fla-PA': 3,
#  'IMDM': 6,
#  'LPS': 7,
#  'LTA': 4,
#  'PGN': 1,
#  'Pam3': 3,
#  'R848': 4}

# %%
from sklearn.feature_selection import chi2, SelectKBest

# Define feature selection
fs = SelectKBest(score_func=chi2, k=500)

# Apply feature selection
X_train = fs.fit_transform(X_train, encoded_labels)

# %%
from sklearn.decomposition import PCA

n_components = 2
pca = PCA(n_components=n_components)
X_train_pca = pca.fit_transform(X_train)

# Scatter plot
plt.scatter(X_train_pca[:, 0], X_train_pca[:, 1], c=encoded_labels, cmap="Set1")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA Visualization of Selected Features")
plt.colorbar(label="Class Label")
plt.show()

# %%
# Transform the test feature matrix
X_test = fs.transform(X_test)

# %%
y_train = pd.get_dummies(y_train, dtype=int)
y_test = pd.get_dummies(y_test, dtype=int)

# %% [markdown]
# ## 4. Build an architecture from scratch or choose a pretrained model

# %%
keras.backend.clear_session()
keras.utils.set_random_seed(2)

# %%
WANDB_NOTEBOOK_NAME = "20230829 NN first sweep"

# %%
sweep_config = {
    "method": "bayes",
    "name": "third_sweep",
    "metric": {
        "name": "Validation AUC",
        "goal": "maximize",
    },
    "parameters": {
        "l1": {"values": [16, 24, 32, 40]},
        "l2": {"values": [16, 24, 32, 40]},
        "epochs": {"values": [200, 280, 320]},
        "learning_rate": {"distribution": "uniform", "min": 0.008, "max": 0.02},
        "batch_size": {"values": [12]},
        "weights_limit": {"distribution": "uniform", "min": 0.008, "max": 0.02},
        "dropout_rates": {"values": [0.2, 0.3, 0.4]},
    },
}

# %%
sweep_id = wandb.sweep(sweep=sweep_config, project="NN-MATseq")
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Create sweep with ID: lbxz4auk
# Sweep URL: https://wandb.ai/afanasyeva-team/NN-MATseq/sweeps/lbxz4auk

# %%
default_config = {
    "l1": 32,
    "l2": 32,
    "dropout_rates": 0.3,
    "batch_size": 12,
    "activation": "relu",
    "weights_limit": 0.0114,
    "epochs": 280,
    "learning_rate": 0.0156,
    "loss": "categorical_crossentropy",
    "optimizer": "adam",
}

# %%
earlystopper = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=3, verbose=0, mode="min", restore_best_weights=True
)

# %%
from wandb.keras import WandbCallback


def train():
    with wandb.init(project="NN-MATseq", config=default_config) as run:
        dropout_rates = run.config.dropout_rates
        batch_size = run.config.batch_size
        activation = run.config.activation
        weights_limit = run.config.weights_limit
        epochs = run.config.epochs
        learning_rate = run.config.learning_rate
        loss = run.config.loss
        l1 = run.config.l1
        l2 = run.config.l2

        if run.config.optimizer == "adam":
            optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
        elif run.config.optimizer == "sgd":
            optimizer = keras.optimizers.SGD(learning_rate=learning_rate)
        elif run.config.optimizer == "rmsprop":
            optimizer = keras.optimizers.RMSprop(learning_rate=learning_rate)

        inputs = keras.Input(shape=X_train.shape[1])
        x = keras.layers.UnitNormalization()(inputs)

        x = keras.layers.Dense(
            l1,
            activation=activation,
            kernel_regularizer=keras.regularizers.L2(weights_limit),
        )(x)
        x = keras.layers.Dropout(dropout_rates)(x)

        x = keras.layers.Dense(
            l2,
            activation=activation,
            kernel_regularizer=keras.regularizers.L2(weights_limit),
        )(x)
        x = keras.layers.Dropout(dropout_rates)(x)

        outputs = keras.layers.Dense(9, activation="softmax")(x)

        model = keras.Model(
            inputs=inputs, outputs=outputs, name="NN_multiclass_classifier_MATseq"
        )

        model.compile(
            optimizer=optimizer,
            loss=loss,
            metrics=[
                "accuracy",
                keras.metrics.AUC(name="auc"),
            ],
        )

        history = model.fit(
            X_train,
            y_train,
            validation_data=(X_test, y_test),
            epochs=epochs,
            batch_size=batch_size,
            verbose=True,
        )

        model.save("NN_multiclass_classifier_MATseq.keras", overwrite=True)

        wandb.log({"AUC": history.history["auc"][-1]})
        wandb.log({"Validation AUC": history.history["val_auc"][-1]})
        wandb.log({"Loss": history.history["loss"][-1]})
        wandb.log({"Validation Loss": history.history["val_loss"][-1]})
        wandb.log({"Accuracy": history.history["accuracy"][-1]})
        wandb.log({"Validation Accuracy": history.history["val_accuracy"][-1]})

# %%
count = 50
wandb.agent(sweep_id, train, count=count)
# Out:
# wandb: Agent Starting Run: co5w5ve0 with config:
# wandb: 	batch_size: 12
# wandb: 	dropout_rates: 0.3
# wandb: 	epochs: 320
# wandb: 	l1: 40
# wandb: 	l2: 40
# wandb: 	learning_rate: 0.013624456548494677
# wandb: 	weights_limit: 0.01618242959789675
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# cat: /sys/module/amdgpu/initstate: No such file or directory
# ERROR:root:Driver not initialized (amdgpu not found in modules)
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/home/t.afanasyeva/MATseq/notebooks/wandb/run-20231106_162020-co5w5ve0</code>
# Syncing run <strong><a href='https://wandb.ai/afanasyeva-team/NN-MATseq/runs/co5w5ve0' target="_blank">worldly-sweep-2</a></strong> to <a href='https://wandb.ai/afanasyeva-team/NN-MATseq' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/afanasyeva-team/NN-MATseq/sweeps/lbxz4auk' target="_blank">https://wandb.ai/afanasyeva-team/NN-MATseq/sweeps/lbxz4auk</a>
#  View project at <a href='https://wandb.ai/afanasyeva-team/NN-MATseq' target="_blank">https://wandb.ai/afanasyeva-team/NN-MATseq</a>
#  View sweep at <a href='https://wandb.ai/afanasyeva-team/NN-MATseq/sweeps/lbxz4auk' target="_blank">https://wandb.ai/afanasyeva-team/NN-MATseq/sweeps/lbxz4auk</a>
#  View run at <a href='https://wandb.ai/afanasyeva-team/NN-MATseq/runs/co5w5ve0' target="_blank">https://wandb.ai/afanasyeva-team/NN-MATseq/runs/co5w5ve0</a>
# Epoch 1/320
# 3/3 [==============================] - 1s 113ms/step - loss: 3.6903 - accuracy: 0.1562 - auc: 0.5303 - val_loss: 3.0172 - val_accuracy: 0.1111 - val_auc: 0.5849
# Epoch 2/320
# 3/3 [==============================] - 0s 26ms/step - loss: 2.8624 - accuracy: 0.1250 - auc: 0.5801 - val_loss: 2.5451 - val_accuracy: 0.2222 - val_auc: 0.6489
# Epoch 3/320
# 3/3 [==============================] - 0s 25ms/step - loss: 2.4848 - accuracy: 0.2500 - auc: 0.6808 - val_loss: 2.3830 - val_accuracy: 0.3333 - val_auc: 0.7608
# Epoch 4/320
# 3/3 [==============================] - 0s 26ms/step - loss: 2.3319 - accuracy: 0.3438 - auc: 0.7449 - val_loss: 2.3138 - val_accuracy: 0.2222 - val_auc: 0.7176
# Epoch 5/320
# 3/3 [==============================] - 0s 25ms/step - loss: 2.2494 - accuracy: 0.2812 - auc: 0.7621 - val_loss: 2.2480 - val_accuracy: 0.3333 - val_auc: 0.7276
# Epoch 6/320
# 3/3 [==============================] - 0s 24ms/step - loss: 2.1428 - accuracy: 0.3438 - auc: 0.7899 - val_loss: 2.1454 - val_accuracy: 0.2222 - val_auc: 0.7415
# Epoch 7/320
# 3/3 [==============================] - 0s 25ms/step - loss: 2.0257 - accuracy: 0.3125 - auc: 0.8030 - val_loss: 2.0807 - val_accuracy: 0.3333 - val_auc: 0.7708
# Epoch 8/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.9665 - accuracy: 0.3750 - auc: 0.8403 - val_loss: 1.9952 - val_accuracy: 0.3333 - val_auc: 0.8187
# Epoch 9/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.8435 - accuracy: 0.4375 - auc: 0.8546 - val_loss: 1.9370 - val_accuracy: 0.4444 - val_auc: 0.8441
# Epoch 10/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.8070 - accuracy: 0.4375 - auc: 0.8777 - val_loss: 1.9143 - val_accuracy: 0.4444 - val_auc: 0.8503
# Epoch 11/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.8528 - accuracy: 0.4375 - auc: 0.8536 - val_loss: 1.8642 - val_accuracy: 0.4444 - val_auc: 0.8611
# Epoch 12/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.7223 - accuracy: 0.4375 - auc: 0.8992 - val_loss: 1.8042 - val_accuracy: 0.5556 - val_auc: 0.8789
# Epoch 13/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.6974 - accuracy: 0.4062 - auc: 0.9001 - val_loss: 1.7870 - val_accuracy: 0.6667 - val_auc: 0.8889
# Epoch 14/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.7526 - accuracy: 0.5000 - auc: 0.8947 - val_loss: 1.7505 - val_accuracy: 0.5556 - val_auc: 0.9028
# Epoch 15/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.5869 - accuracy: 0.5625 - auc: 0.9194 - val_loss: 1.7123 - val_accuracy: 0.6667 - val_auc: 0.9074
# Epoch 16/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.6997 - accuracy: 0.5625 - auc: 0.9020 - val_loss: 1.7739 - val_accuracy: 0.5556 - val_auc: 0.8889
# Epoch 17/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.6888 - accuracy: 0.5625 - auc: 0.9072 - val_loss: 1.7222 - val_accuracy: 0.6667 - val_auc: 0.9066
# Epoch 18/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.4910 - accuracy: 0.5625 - auc: 0.9448 - val_loss: 1.6475 - val_accuracy: 0.6667 - val_auc: 0.9213
# Epoch 19/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.4463 - accuracy: 0.7500 - auc: 0.9567 - val_loss: 1.7997 - val_accuracy: 0.3333 - val_auc: 0.8804
# Epoch 20/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.5840 - accuracy: 0.5625 - auc: 0.9294 - val_loss: 1.7000 - val_accuracy: 0.5556 - val_auc: 0.9136
# Epoch 21/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.5519 - accuracy: 0.5625 - auc: 0.9362 - val_loss: 1.5859 - val_accuracy: 0.6667 - val_auc: 0.9329
# Epoch 22/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.6013 - accuracy: 0.5000 - auc: 0.9312 - val_loss: 1.6021 - val_accuracy: 0.6667 - val_auc: 0.9414
# Epoch 23/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.4281 - accuracy: 0.7188 - auc: 0.9631 - val_loss: 1.5848 - val_accuracy: 0.6667 - val_auc: 0.9414
# Epoch 24/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.5462 - accuracy: 0.6562 - auc: 0.9478 - val_loss: 1.5862 - val_accuracy: 0.6667 - val_auc: 0.9414
# Epoch 25/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.4185 - accuracy: 0.7188 - auc: 0.9675 - val_loss: 1.4836 - val_accuracy: 0.6667 - val_auc: 0.9622
# Epoch 26/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.3026 - accuracy: 0.7500 - auc: 0.9717 - val_loss: 1.6329 - val_accuracy: 0.6667 - val_auc: 0.9313
# Epoch 27/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.4361 - accuracy: 0.7188 - auc: 0.9574 - val_loss: 1.5301 - val_accuracy: 0.7778 - val_auc: 0.9560
# Epoch 28/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.4153 - accuracy: 0.8125 - auc: 0.9659 - val_loss: 1.4481 - val_accuracy: 0.7778 - val_auc: 0.9599
# Epoch 29/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.3591 - accuracy: 0.7188 - auc: 0.9691 - val_loss: 1.4562 - val_accuracy: 0.6667 - val_auc: 0.9583
# Epoch 30/320
# 3/3 [==============================] - 0s 27ms/step - loss: 1.3285 - accuracy: 0.7500 - auc: 0.9739 - val_loss: 1.5451 - val_accuracy: 0.5556 - val_auc: 0.9522
# Epoch 31/320
# 3/3 [==============================] - 0s 23ms/step - loss: 1.4539 - accuracy: 0.6562 - auc: 0.9574 - val_loss: 1.5439 - val_accuracy: 0.6667 - val_auc: 0.9475
# Epoch 32/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.3275 - accuracy: 0.7500 - auc: 0.9745 - val_loss: 1.4255 - val_accuracy: 0.7778 - val_auc: 0.9769
# Epoch 33/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.3212 - accuracy: 0.8125 - auc: 0.9788 - val_loss: 1.3794 - val_accuracy: 0.6667 - val_auc: 0.9738
# Epoch 34/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.3457 - accuracy: 0.7188 - auc: 0.9734 - val_loss: 1.3459 - val_accuracy: 0.6667 - val_auc: 0.9707
# Epoch 35/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1228 - accuracy: 0.7812 - auc: 0.9882 - val_loss: 1.3920 - val_accuracy: 0.7778 - val_auc: 0.9691
# Epoch 36/320
# 1/3 [=========>....................] - ETA: 0s - loss: 1.6172 - accuracy: 0.5833 - auc: 0.9288
# wandb: Ctrl + C detected. Stopping sweep.
# Error in callback <bound method _WandbInit._pause_backend of <wandb.sdk.wandb_init._WandbInit object at 0x7f806b097820>> (for post_run_cell), with arguments args (<ExecutionResult object at 7f806b2e4250, execution_count=25 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 7f845a603550, raw_cell="count = 50
# wandb.agent(sweep_id, train, count=coun.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell://ssh-remote%2B172.25.84.250/home/t.afanasyeva/MATseq/notebooks/20230831%20nn%20third%20sweep.ipynb#X40sdnNjb2RlLXJlbW90ZQ%3D%3D> result=None>,),kwargs {}:
# 3/3 [==============================] - 0s 26ms/step - loss: 1.3144 - accuracy: 0.7500 - auc: 0.9675 - val_loss: 1.3683 - val_accuracy: 0.6667 - val_auc: 0.9753
# Epoch 37/320
# 3/3 [==============================] - 0s 28ms/step - loss: 1.1487 - accuracy: 0.9062 - auc: 0.9917 - val_loss: 1.3706 - val_accuracy: 0.7778 - val_auc: 0.9707
# Epoch 38/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1601 - accuracy: 0.8750 - auc: 0.9937 - val_loss: 1.4762 - val_accuracy: 0.7778 - val_auc: 0.9560
# Epoch 39/320
# 3/3 [==============================] - 0s 30ms/step - loss: 1.2150 - accuracy: 0.7812 - auc: 0.9835 - val_loss: 1.3255 - val_accuracy: 0.7778 - val_auc: 0.9769
# Epoch 40/320
# 3/3 [==============================] - 0s 27ms/step - loss: 1.3243 - accuracy: 0.7188 - auc: 0.9682 - val_loss: 1.4038 - val_accuracy: 0.7778 - val_auc: 0.9722
# Epoch 41/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.2933 - accuracy: 0.7500 - auc: 0.9775 - val_loss: 1.3234 - val_accuracy: 0.7778 - val_auc: 0.9792
# Epoch 42/320
# 3/3 [==============================] - 0s 27ms/step - loss: 1.2958 - accuracy: 0.6875 - auc: 0.9752 - val_loss: 1.3545 - val_accuracy: 0.7778 - val_auc: 0.9761
# Epoch 43/320
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0825 - accuracy: 0.9167 - auc: 0.9983
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: _WandbInit._pause_backend() takes 1 positional argument but 2 were given
# 3/3 [==============================] - 0s 31ms/step - loss: 1.1797 - accuracy: 0.9062 - auc: 0.9949 - val_loss: 1.3459 - val_accuracy: 0.6667 - val_auc: 0.9769
# Epoch 44/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.2631 - accuracy: 0.8125 - auc: 0.9792 - val_loss: 1.4090 - val_accuracy: 0.6667 - val_auc: 0.9660
# Epoch 45/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.2083 - accuracy: 0.7500 - auc: 0.9831 - val_loss: 1.3363 - val_accuracy: 0.6667 - val_auc: 0.9722
# Epoch 46/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.3142 - accuracy: 0.7812 - auc: 0.9701 - val_loss: 1.4273 - val_accuracy: 0.6667 - val_auc: 0.9552
# Epoch 47/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0674 - accuracy: 0.8750 - auc: 0.9907 - val_loss: 1.3664 - val_accuracy: 0.6667 - val_auc: 0.9799
# Epoch 48/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.2507 - accuracy: 0.8438 - auc: 0.9835 - val_loss: 1.2803 - val_accuracy: 0.6667 - val_auc: 0.9877
# Epoch 49/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.2762 - accuracy: 0.8438 - auc: 0.9747 - val_loss: 1.4303 - val_accuracy: 0.7778 - val_auc: 0.9529
# Epoch 50/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.2392 - accuracy: 0.7500 - auc: 0.9798 - val_loss: 1.4469 - val_accuracy: 0.6667 - val_auc: 0.9560
# Epoch 51/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.3383 - accuracy: 0.6562 - auc: 0.9664 - val_loss: 1.4654 - val_accuracy: 0.6667 - val_auc: 0.9560
# Epoch 52/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1408 - accuracy: 0.8438 - auc: 0.9906 - val_loss: 1.5574 - val_accuracy: 0.6667 - val_auc: 0.9506
# Epoch 53/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.3088 - accuracy: 0.7812 - auc: 0.9821 - val_loss: 1.4665 - val_accuracy: 0.7778 - val_auc: 0.9684
# Epoch 54/320
# 3/3 [==============================] - 0s 25ms/step - loss: 0.9786 - accuracy: 0.9688 - auc: 0.9997 - val_loss: 1.4546 - val_accuracy: 0.6667 - val_auc: 0.9622
# Epoch 55/320
# 3/3 [==============================] - 0s 27ms/step - loss: 1.3672 - accuracy: 0.8438 - auc: 0.9719 - val_loss: 1.3786 - val_accuracy: 0.6667 - val_auc: 0.9676
# Epoch 56/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.3668 - accuracy: 0.7188 - auc: 0.9658 - val_loss: 1.5463 - val_accuracy: 0.7778 - val_auc: 0.9483
# Epoch 57/320
# 3/3 [==============================] - 0s 29ms/step - loss: 1.2573 - accuracy: 0.7500 - auc: 0.9833 - val_loss: 1.5024 - val_accuracy: 0.7778 - val_auc: 0.9645
# Epoch 58/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.1842 - accuracy: 0.9375 - auc: 0.9922 - val_loss: 1.3613 - val_accuracy: 0.7778 - val_auc: 0.9846
# Epoch 59/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1497 - accuracy: 0.9062 - auc: 0.9948 - val_loss: 1.3494 - val_accuracy: 0.7778 - val_auc: 0.9807
# Epoch 60/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0781 - accuracy: 0.9688 - auc: 0.9984 - val_loss: 1.3470 - val_accuracy: 0.6667 - val_auc: 0.9738
# Epoch 61/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.1209 - accuracy: 0.8438 - auc: 0.9948 - val_loss: 1.5757 - val_accuracy: 0.7778 - val_auc: 0.9437
# Epoch 62/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0805 - accuracy: 0.9062 - auc: 0.9915 - val_loss: 1.3588 - val_accuracy: 0.6667 - val_auc: 0.9668
# Epoch 63/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0067 - accuracy: 0.9062 - auc: 0.9960 - val_loss: 1.3076 - val_accuracy: 0.6667 - val_auc: 0.9738
# Epoch 64/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1395 - accuracy: 0.8125 - auc: 0.9858 - val_loss: 1.2668 - val_accuracy: 0.7778 - val_auc: 0.9769
# Epoch 65/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.1625 - accuracy: 0.8125 - auc: 0.9853 - val_loss: 1.3270 - val_accuracy: 0.6667 - val_auc: 0.9684
# Epoch 66/320
# 3/3 [==============================] - 0s 24ms/step - loss: 0.9570 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 1.4277 - val_accuracy: 0.5556 - val_auc: 0.9552
# Epoch 67/320
# 3/3 [==============================] - 0s 25ms/step - loss: 0.9668 - accuracy: 0.8750 - auc: 0.9933 - val_loss: 1.2585 - val_accuracy: 0.7778 - val_auc: 0.9745
# Epoch 68/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1329 - accuracy: 0.9062 - auc: 0.9865 - val_loss: 1.3193 - val_accuracy: 0.6667 - val_auc: 0.9745
# Epoch 69/320
# 3/3 [==============================] - 0s 25ms/step - loss: 0.9693 - accuracy: 0.9062 - auc: 0.9960 - val_loss: 1.3201 - val_accuracy: 0.6667 - val_auc: 0.9691
# Epoch 70/320
# 3/3 [==============================] - 0s 25ms/step - loss: 0.9992 - accuracy: 0.9062 - auc: 0.9951 - val_loss: 1.4209 - val_accuracy: 0.7778 - val_auc: 0.9552
# Epoch 71/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0680 - accuracy: 0.8750 - auc: 0.9883 - val_loss: 1.3697 - val_accuracy: 0.6667 - val_auc: 0.9653
# Epoch 72/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.0445 - accuracy: 0.8750 - auc: 0.9920 - val_loss: 1.1647 - val_accuracy: 0.7778 - val_auc: 0.9815
# Epoch 73/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1003 - accuracy: 0.7500 - auc: 0.9864 - val_loss: 1.1941 - val_accuracy: 0.8889 - val_auc: 0.9830
# Epoch 74/320
# 3/3 [==============================] - 0s 27ms/step - loss: 1.0033 - accuracy: 0.9062 - auc: 0.9923 - val_loss: 1.3507 - val_accuracy: 0.7778 - val_auc: 0.9676
# Epoch 75/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0830 - accuracy: 0.9062 - auc: 0.9881 - val_loss: 1.3291 - val_accuracy: 0.7778 - val_auc: 0.9645
# Epoch 76/320
# 3/3 [==============================] - 0s 27ms/step - loss: 1.0577 - accuracy: 0.8125 - auc: 0.9908 - val_loss: 1.2071 - val_accuracy: 0.7778 - val_auc: 0.9792
# Epoch 77/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1745 - accuracy: 0.7812 - auc: 0.9812 - val_loss: 1.3540 - val_accuracy: 0.6667 - val_auc: 0.9645
# Epoch 78/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.2759 - accuracy: 0.8125 - auc: 0.9739 - val_loss: 1.4096 - val_accuracy: 0.7778 - val_auc: 0.9630
# Epoch 79/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.2142 - accuracy: 0.7188 - auc: 0.9832 - val_loss: 1.3395 - val_accuracy: 0.7778 - val_auc: 0.9676
# Epoch 80/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1556 - accuracy: 0.8750 - auc: 0.9882 - val_loss: 1.4037 - val_accuracy: 0.6667 - val_auc: 0.9591
# Epoch 81/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.3516 - accuracy: 0.6875 - auc: 0.9702 - val_loss: 1.5687 - val_accuracy: 0.6667 - val_auc: 0.9468
# Epoch 82/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.2012 - accuracy: 0.8125 - auc: 0.9855 - val_loss: 1.5527 - val_accuracy: 0.7778 - val_auc: 0.9537
# Epoch 83/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.2280 - accuracy: 0.8125 - auc: 0.9821 - val_loss: 1.4192 - val_accuracy: 0.7778 - val_auc: 0.9660
# Epoch 84/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.1303 - accuracy: 0.8438 - auc: 0.9876 - val_loss: 1.3855 - val_accuracy: 0.7778 - val_auc: 0.9707
# Epoch 85/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.0080 - accuracy: 0.9375 - auc: 0.9968 - val_loss: 1.4625 - val_accuracy: 0.6667 - val_auc: 0.9568
# Epoch 86/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.1704 - accuracy: 0.8125 - auc: 0.9858 - val_loss: 1.2918 - val_accuracy: 0.7778 - val_auc: 0.9753
# Epoch 87/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.1134 - accuracy: 0.8438 - auc: 0.9921 - val_loss: 1.1589 - val_accuracy: 0.7778 - val_auc: 0.9907
# Epoch 88/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1904 - accuracy: 0.8125 - auc: 0.9812 - val_loss: 1.3238 - val_accuracy: 0.6667 - val_auc: 0.9676
# Epoch 89/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0248 - accuracy: 0.8125 - auc: 0.9920 - val_loss: 1.3746 - val_accuracy: 0.6667 - val_auc: 0.9606
# Epoch 90/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0757 - accuracy: 0.7812 - auc: 0.9891 - val_loss: 1.2652 - val_accuracy: 0.7778 - val_auc: 0.9792
# Epoch 91/320
# 3/3 [==============================] - 0s 27ms/step - loss: 0.9093 - accuracy: 0.9375 - auc: 0.9969 - val_loss: 1.2334 - val_accuracy: 0.7778 - val_auc: 0.9799
# Epoch 92/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0716 - accuracy: 0.8125 - auc: 0.9910 - val_loss: 1.2815 - val_accuracy: 0.7778 - val_auc: 0.9707
# Epoch 93/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0237 - accuracy: 0.9375 - auc: 0.9949 - val_loss: 1.2096 - val_accuracy: 0.6667 - val_auc: 0.9769
# Epoch 94/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0504 - accuracy: 0.8125 - auc: 0.9886 - val_loss: 1.5151 - val_accuracy: 0.7778 - val_auc: 0.9421
# Epoch 95/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1077 - accuracy: 0.7188 - auc: 0.9838 - val_loss: 1.5112 - val_accuracy: 0.6667 - val_auc: 0.9475
# Epoch 96/320
# 3/3 [==============================] - 0s 24ms/step - loss: 0.9696 - accuracy: 0.9062 - auc: 0.9951 - val_loss: 1.1827 - val_accuracy: 0.8889 - val_auc: 0.9830
# Epoch 97/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1096 - accuracy: 0.8438 - auc: 0.9822 - val_loss: 1.1589 - val_accuracy: 0.7778 - val_auc: 0.9900
# Epoch 98/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0495 - accuracy: 0.8438 - auc: 0.9923 - val_loss: 1.4083 - val_accuracy: 0.7778 - val_auc: 0.9653
# Epoch 99/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1453 - accuracy: 0.8438 - auc: 0.9858 - val_loss: 1.6054 - val_accuracy: 0.7778 - val_auc: 0.9491
# Epoch 100/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1263 - accuracy: 0.8125 - auc: 0.9857 - val_loss: 1.5127 - val_accuracy: 0.6667 - val_auc: 0.9545
# Epoch 101/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.2297 - accuracy: 0.8438 - auc: 0.9797 - val_loss: 1.3736 - val_accuracy: 0.6667 - val_auc: 0.9730
# Epoch 102/320
# 3/3 [==============================] - 0s 25ms/step - loss: 0.9453 - accuracy: 0.9375 - auc: 0.9980 - val_loss: 1.3304 - val_accuracy: 0.6667 - val_auc: 0.9784
# Epoch 103/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.2520 - accuracy: 0.8750 - auc: 0.9633 - val_loss: 1.3749 - val_accuracy: 0.6667 - val_auc: 0.9730
# Epoch 104/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0108 - accuracy: 0.9062 - auc: 0.9957 - val_loss: 1.7197 - val_accuracy: 0.5556 - val_auc: 0.9252
# Epoch 105/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0629 - accuracy: 0.9062 - auc: 0.9957 - val_loss: 1.4812 - val_accuracy: 0.6667 - val_auc: 0.9606
# Epoch 106/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.2285 - accuracy: 0.8438 - auc: 0.9811 - val_loss: 1.2797 - val_accuracy: 0.7778 - val_auc: 0.9799
# Epoch 107/320
# 3/3 [==============================] - 0s 26ms/step - loss: 0.9158 - accuracy: 0.9375 - auc: 0.9988 - val_loss: 1.2576 - val_accuracy: 0.7778 - val_auc: 0.9769
# Epoch 108/320
# 3/3 [==============================] - 0s 25ms/step - loss: 0.8898 - accuracy: 0.9375 - auc: 0.9985 - val_loss: 1.4559 - val_accuracy: 0.6667 - val_auc: 0.9537
# Epoch 109/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.0667 - accuracy: 0.8125 - auc: 0.9880 - val_loss: 1.5041 - val_accuracy: 0.7778 - val_auc: 0.9414
# Epoch 110/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0095 - accuracy: 0.8438 - auc: 0.9919 - val_loss: 1.2487 - val_accuracy: 0.6667 - val_auc: 0.9668
# Epoch 111/320
# 3/3 [==============================] - 0s 26ms/step - loss: 0.9230 - accuracy: 0.8750 - auc: 0.9945 - val_loss: 1.4084 - val_accuracy: 0.6667 - val_auc: 0.9552
# Epoch 112/320
# 3/3 [==============================] - 0s 25ms/step - loss: 0.9435 - accuracy: 0.8750 - auc: 0.9961 - val_loss: 1.7023 - val_accuracy: 0.6667 - val_auc: 0.9414
# Epoch 113/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0154 - accuracy: 0.8750 - auc: 0.9911 - val_loss: 1.2271 - val_accuracy: 0.7778 - val_auc: 0.9799
# Epoch 114/320
# 3/3 [==============================] - 0s 25ms/step - loss: 0.8520 - accuracy: 0.9688 - auc: 0.9998 - val_loss: 1.2053 - val_accuracy: 0.7778 - val_auc: 0.9799
# Epoch 115/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.2711 - accuracy: 0.7188 - auc: 0.9747 - val_loss: 1.4844 - val_accuracy: 0.6667 - val_auc: 0.9568
# Epoch 116/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1484 - accuracy: 0.7812 - auc: 0.9826 - val_loss: 1.3922 - val_accuracy: 0.7778 - val_auc: 0.9684
# Epoch 117/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0110 - accuracy: 0.8125 - auc: 0.9945 - val_loss: 1.3801 - val_accuracy: 0.6667 - val_auc: 0.9660
# Epoch 118/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0663 - accuracy: 0.8750 - auc: 0.9893 - val_loss: 1.3577 - val_accuracy: 0.6667 - val_auc: 0.9691
# Epoch 119/320
# 3/3 [==============================] - 0s 25ms/step - loss: 0.8530 - accuracy: 0.9062 - auc: 0.9983 - val_loss: 1.5588 - val_accuracy: 0.7778 - val_auc: 0.9329
# Epoch 120/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.0894 - accuracy: 0.8438 - auc: 0.9827 - val_loss: 1.3899 - val_accuracy: 0.7778 - val_auc: 0.9552
# Epoch 121/320
# 3/3 [==============================] - 0s 25ms/step - loss: 0.9939 - accuracy: 0.8750 - auc: 0.9899 - val_loss: 1.3213 - val_accuracy: 0.7778 - val_auc: 0.9653
# Epoch 122/320
# 3/3 [==============================] - 0s 25ms/step - loss: 0.8468 - accuracy: 0.9062 - auc: 0.9981 - val_loss: 1.4049 - val_accuracy: 0.7778 - val_auc: 0.9522
# Epoch 123/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0616 - accuracy: 0.8438 - auc: 0.9843 - val_loss: 1.3975 - val_accuracy: 0.6667 - val_auc: 0.9552
# Epoch 124/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.2244 - accuracy: 0.7188 - auc: 0.9715 - val_loss: 1.1729 - val_accuracy: 0.7778 - val_auc: 0.9792
# Epoch 125/320
# 3/3 [==============================] - 0s 24ms/step - loss: 0.9627 - accuracy: 0.8750 - auc: 0.9854 - val_loss: 1.2065 - val_accuracy: 0.8889 - val_auc: 0.9823
# Epoch 126/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.0473 - accuracy: 0.8750 - auc: 0.9888 - val_loss: 1.1819 - val_accuracy: 0.8889 - val_auc: 0.9861
# Epoch 127/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0354 - accuracy: 0.9062 - auc: 0.9899 - val_loss: 1.2256 - val_accuracy: 0.7778 - val_auc: 0.9753
# Epoch 128/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1073 - accuracy: 0.8750 - auc: 0.9827 - val_loss: 1.2398 - val_accuracy: 0.6667 - val_auc: 0.9738
# Epoch 129/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.1884 - accuracy: 0.8438 - auc: 0.9745 - val_loss: 1.3843 - val_accuracy: 0.7778 - val_auc: 0.9576
# Epoch 130/320
# 3/3 [==============================] - 0s 25ms/step - loss: 0.9065 - accuracy: 0.9375 - auc: 0.9977 - val_loss: 1.3552 - val_accuracy: 0.7778 - val_auc: 0.9583
# Epoch 131/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.0804 - accuracy: 0.8438 - auc: 0.9836 - val_loss: 1.1493 - val_accuracy: 0.7778 - val_auc: 0.9830
# Epoch 132/320
# 3/3 [==============================] - 0s 26ms/step - loss: 1.2150 - accuracy: 0.7500 - auc: 0.9695 - val_loss: 1.1762 - val_accuracy: 0.6667 - val_auc: 0.9815
# Epoch 133/320
# 3/3 [==============================] - 0s 25ms/step - loss: 0.9228 - accuracy: 0.8438 - auc: 0.9935 - val_loss: 1.2401 - val_accuracy: 0.6667 - val_auc: 0.9769
# Epoch 134/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1046 - accuracy: 0.8438 - auc: 0.9824 - val_loss: 1.1869 - val_accuracy: 0.7778 - val_auc: 0.9861
# Epoch 135/320
# 3/3 [==============================] - 0s 24ms/step - loss: 0.9989 - accuracy: 0.8750 - auc: 0.9957 - val_loss: 1.2607 - val_accuracy: 0.7778 - val_auc: 0.9738
# Epoch 136/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0725 - accuracy: 0.7500 - auc: 0.9886 - val_loss: 1.3807 - val_accuracy: 0.7778 - val_auc: 0.9583
# Epoch 137/320
# 3/3 [==============================] - 0s 24ms/step - loss: 0.8692 - accuracy: 1.0000 - auc: 0.9995 - val_loss: 1.3564 - val_accuracy: 0.6667 - val_auc: 0.9653
# Epoch 138/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.2366 - accuracy: 0.7812 - auc: 0.9719 - val_loss: 1.2926 - val_accuracy: 0.6667 - val_auc: 0.9707
# Epoch 139/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.1560 - accuracy: 0.8125 - auc: 0.9780 - val_loss: 1.1836 - val_accuracy: 0.7778 - val_auc: 0.9799
# Epoch 140/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0074 - accuracy: 0.8438 - auc: 0.9896 - val_loss: 1.2528 - val_accuracy: 0.7778 - val_auc: 0.9676
# Epoch 141/320
# 3/3 [==============================] - 0s 27ms/step - loss: 1.0948 - accuracy: 0.7812 - auc: 0.9805 - val_loss: 1.1390 - val_accuracy: 0.7778 - val_auc: 0.9846
# Epoch 142/320
# 3/3 [==============================] - 0s 27ms/step - loss: 0.9859 - accuracy: 0.9062 - auc: 0.9886 - val_loss: 1.1973 - val_accuracy: 0.6667 - val_auc: 0.9753
# Epoch 143/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0950 - accuracy: 0.7188 - auc: 0.9826 - val_loss: 1.3734 - val_accuracy: 0.6667 - val_auc: 0.9576
# Epoch 144/320
# 3/3 [==============================] - 0s 23ms/step - loss: 0.8902 - accuracy: 0.9688 - auc: 0.9970 - val_loss: 1.6185 - val_accuracy: 0.7778 - val_auc: 0.9390
# Epoch 145/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0884 - accuracy: 0.7500 - auc: 0.9841 - val_loss: 1.4549 - val_accuracy: 0.6667 - val_auc: 0.9545
# Epoch 146/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0885 - accuracy: 0.8438 - auc: 0.9862 - val_loss: 1.3619 - val_accuracy: 0.6667 - val_auc: 0.9630
# Epoch 147/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.0022 - accuracy: 0.8438 - auc: 0.9926 - val_loss: 1.4780 - val_accuracy: 0.7778 - val_auc: 0.9545
# Epoch 148/320
# 3/3 [==============================] - 0s 24ms/step - loss: 1.3208 - accuracy: 0.6562 - auc: 0.9661 - val_loss: 1.4925 - val_accuracy: 0.5556 - val_auc: 0.9529
# Epoch 149/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0134 - accuracy: 0.8438 - auc: 0.9915 - val_loss: 1.2601 - val_accuracy: 0.7778 - val_auc: 0.9753
# Epoch 150/320
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0849 - accuracy: 0.8125 - auc: 0.9865 - val_loss: 1.3220 - val_accuracy: 0.6667 - val_auc: 0.9691
# Epoch 151/320
# 3/3 [==============================] - 0s 25ms/step - loss: 0.9876 - accuracy: 0.8125 - auc: 0.9940 - val_loss: 1.6666 - val_accuracy: 0.7778 - val_auc: 0.8935
# Epoch 152/320
# Traceback (most recent call last):
