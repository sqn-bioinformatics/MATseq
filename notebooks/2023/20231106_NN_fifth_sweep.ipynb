# %% [markdown]
# # Fifth sweep Neural network for classification of contaminants with MAT

# %% [markdown]
# 2023-11-06

# %% [markdown]
# ## 1. Formulate/outline the problem: classification

# %% [markdown]
# Simple neural network for classification of the contaminants using MAT transcriptomes

# %% [markdown]
# ## 2. Data preprocessing

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import wandb
import tensorflow as tf
from tensorflow import keras

# %%
import random
from sklearn.base import BaseEstimator, TransformerMixin


def select_samples(name, n=None, sample_names_to_check=None):
    index_list = []
    for index, sample_description in enumerate(sample_names_to_check):
        if name in sample_description and len(name) == len(sample_description):
            print(name)
            index_list.append(index)

    return index_list[:n]


class LibraryLengthNormalizer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X, y=None):
        # Normalise the gene counts to the library size
        X = X.apply(lambda x: (x / (x.sum() if x.sum() != 0 else 1)) * 1000000)
        return X

# %%
included_sample_names = [
    "CL-307",
    "CRX-527",
    "Fla-PA",
    "IMDM",
    "LPS",
    "LTA",
    "PGN",
    "Pam3",
    "R848",
]

# %%
file_name = "/home/t.afanasyeva/MATseq/notebooks/gene_counts_7128_old_64_train.csv"
data = pd.read_csv(file_name)

labels = data["sample"]
features = data.drop(columns=["sample"])

# %%
from sklearn.neighbors import LocalOutlierFactor

clf = LocalOutlierFactor(n_neighbors=4)
outliers = clf.fit_predict(features)
mask = [outlier != -1 for outlier in outliers]
features = features[mask]
labels = labels[mask]

features_train = features.reset_index(drop=True)
labels_train = labels.reset_index(drop=True)

# %%
X_train = features_train

# %%
y_train = labels_train

# %%
file_name = "/home/t.afanasyeva/MATseq/notebooks/gene_counts_105_test_set.csv"
data = pd.read_csv(file_name)


labels = data["sample"]
features = data.drop(columns=["sample"])

# %%
index_list = []
for name in included_sample_names:
    index_list.extend(select_samples(name, n=500, sample_names_to_check=labels))

features_test = features.iloc[index_list]
labels_test = labels.iloc[index_list]
# Out:
# Fla-PA
# Fla-PA
# Fla-PA
# Fla-PA
# Fla-PA
# Fla-PA
# Fla-PA
# Fla-PA
# Fla-PA
# Fla-PA
# Fla-PA
# Fla-PA
# Fla-PA
# Fla-PA
# Fla-PA
# IMDM
# IMDM
# IMDM
# IMDM
# IMDM
# IMDM
# IMDM
# IMDM
# IMDM
# IMDM
# IMDM
# IMDM
# IMDM
# IMDM
# LPS
# LPS
# LPS
# LPS
# LPS
# LPS
# LPS
# LPS
# LPS
# LPS
# LPS
# LPS
# LPS
# LPS
# LPS
# LPS
# LTA
# LTA
# LTA
# Pam3
# Pam3
# Pam3
# Pam3
# Pam3
# Pam3
# Pam3
# Pam3
# Pam3
# Pam3
# Pam3
# Pam3
# R848
# R848
# R848
# R848
# R848
# R848
# R848
# R848
# R848
# R848
# R848
# R848
# R848
# R848
# R848
# R848
# R848
# R848

# %%
X_test = features_test

# %%
y_test = labels_test

# %%
import time
from sklearn.pipeline import Pipeline
from feature_engine.selection import (
    DropDuplicateFeatures,
    DropConstantFeatures,
)
from feature_engine.outliers import Winsorizer
from sklearn.preprocessing import PowerTransformer

from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectKBest, chi2, SelectFromModel

forest = ExtraTreesClassifier(n_estimators=250, max_depth=5, random_state=1)


feature_transformer = Pipeline(
    [
        (
            "drop_duplicates",
            DropDuplicateFeatures(),
        ),  # insert a transformer that converts everything under 10 to 0
        ("drop_constant_feature", DropConstantFeatures(tol=0.50)),
        ("normalise_for_library_size", LibraryLengthNormalizer()),
        ("cap_outliers", Winsorizer(capping_method="gaussian", tail="right", fold=3)),
    ]
)

feature_selector = Pipeline(
    [
        ("select_k_best", SelectKBest(chi2, k=1000)),
        (
            "trasnform_and_scale",
            PowerTransformer(method="yeo-johnson", standardize=True),
        ),
        ("select_forest", SelectFromModel(forest, max_features=500)),
    ]
)

print("Number of features before: ", X_train.shape[1])
start_time = time.time()


X_train = feature_transformer.fit_transform(X_train)
X_test = feature_transformer.transform(X_test)

feature_selector.fit(X_train, y_train)
X_train = feature_selector.transform(X_train)
X_test = feature_selector.transform(X_test)

end_time = time.time()
print("Number of features after: ", X_train.shape[1])
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Number of features before:  19992
# Number of features after:  322
# Elapsed time: 30.643081426620483 seconds

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# %%
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
num_classes = y_train.shape[1]
num_classes
# Out:
# 9

# %%
from sklearn.model_selection import train_test_split

split_params = {
    "test_size": 0.2,
    "random_state": 0,
    "shuffle": True,
}


X_train, X_val, y_train, y_val = train_test_split(
    X_train,
    y_train,
    **split_params,
    stratify=y_train,
)

# %% [markdown]
# ## 3. Build an architecture

# %%
keras.backend.clear_session()
keras.utils.set_random_seed(2)

# %%
WANDB_NOTEBOOK_NAME = "20231106 NN fifth sweep"

# %%
sweep_config = {
    "method": "bayes",
    "name": "third_sweep",
    "metric": {
        "name": "Validation AUC",
        "goal": "maximize",
    },
    "parameters": {
        "l1": {"values": [16, 24, 32, 40]},
        "l2": {"values": [16, 24, 32, 40]},
        "epochs": {"values": [200, 280, 320]},
        "learning_rate": {"distribution": "uniform", "min": 0.008, "max": 0.02},
        "batch_size": {"values": [12]},
        "weights_limit": {"distribution": "uniform", "min": 0.008, "max": 0.02},
        "dropout_rates": {"values": [0.2, 0.3, 0.4]},
    },
}

# %%
sweep_id = wandb.sweep(sweep=sweep_config, project="NN-MATseq")
# Out:
# Create sweep with ID: fnhp0fsv
# Sweep URL: https://wandb.ai/afanasyeva-team/NN-MATseq/sweeps/fnhp0fsv

# %%
file_path = "/home/t.afanasyeva/MATseq/notebooks/model_zoo"

checkpoint_callback = keras.callbacks.ModelCheckpoint(
    filepath=file_path,
    save_weights_only=False,
    monitor="loss",
    verbose=1,
    save_best_only=True,
    mode="min",
)

# %%
default_config = {
    "l1": 100,
    "l2": 80,
    "l3": 27,
    "batch_size": 8,
    "activation": "elu",
    "weights_limit": 0.001,
    "epochs": 400,
    "learning_rate": 0.001,
    "loss": "categorical_crossentropy",
    "optimizer": "adam",
    "dropout_rate1": 0.2,
    "dropout_rate2": 0.5,
    "dropout_rate3": 0.8,
}

# %%
sweep_config = {
    "method": "bayes",
    "name": "fifth_sweep",
    "metric": {
        "name": "validation_loss",
        "goal": "minimize",
    },
    "parameters": {
        "l1": {"values": [100, 120, 150]},
        "l2": {"values": [60, 70, 80, 90]},
        "l3": {"values": [18, 27]},
        "learning_rate": {"distribution": "uniform", "min": 0.0001, "max": 0.01},
        "batch_size": {"values": [8, 10, 12]},
        "weights_limit": {"distribution": "uniform", "min": 0.0001, "max": 0.01},
    },
}

# %%
from tensorflow.keras.initializers import HeUniform


def train():
    with tf.device("/GPU:0"):
        with wandb.init(project="NN-MATseq", config=default_config) as run:
            batch_size = run.config.batch_size
            activation = run.config.activation
            weights_limit = run.config.weights_limit
            epochs = run.config.epochs
            learning_rate = run.config.learning_rate
            loss = run.config.loss
            l1 = run.config.l1
            l2 = run.config.l2
            l3 = run.config.l3
            dropout_rate1 = run.config.dropout_rate1
            dropout_rate2 = run.config.dropout_rate2
            dropout_rate3 = run.config.dropout_rate3

            if run.config.optimizer == "adam":
                optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
            elif run.config.optimizer == "sgd":
                optimizer = keras.optimizers.SGD(learning_rate=learning_rate)
            elif run.config.optimizer == "rmsprop":
                optimizer = keras.optimizers.RMSprop(learning_rate=learning_rate)

            inputs = keras.Input(shape=X_train.shape[1])
            x = keras.layers.UnitNormalization()(inputs)

            x = keras.layers.Dense(
                l1,
                activation=activation,
                kernel_regularizer=keras.regularizers.L2(weights_limit),
                kernel_initializer=HeUniform(),
            )(x)
            x = keras.layers.Dropout(dropout_rate1)(x)

            x = keras.layers.Dense(
                l2,
                activation=activation,
                kernel_regularizer=keras.regularizers.L2(weights_limit),
                kernel_initializer=HeUniform(),
            )(x)
            x = keras.layers.Dropout(dropout_rate2)(x)

            x = keras.layers.Dense(
                l3,
                activation=activation,
                kernel_regularizer=keras.regularizers.L2(weights_limit),
                kernel_initializer=HeUniform(),
            )(x)
            x = keras.layers.Dropout(dropout_rate3)(x)

            outputs = keras.layers.Dense(9, activation="softmax")(x)

            model = keras.Model(
                inputs=inputs,
                outputs=outputs,
                name="MATseq_NN_multiclass_classifier_v0.3",
            )

            model.compile(
                optimizer=optimizer,
                loss=loss,
                metrics=[
                    "accuracy",
                    keras.metrics.AUC(name="auc"),
                ],
            )

            history = model.fit(
                X_train,
                y_train,
                validation_data=(X_val, y_val),
                epochs=epochs,
                batch_size=batch_size,
                verbose=True,
                callbacks=[
                    wandb.keras.WandbCallback(),
                    checkpoint_callback,
                ],
            )

# %%
count = 50
wandb.agent(sweep_id, train, count=count)
# Out:
# wandb: Agent Starting Run: 1bflri29 with config:
# wandb: 	batch_size: 12
# wandb: 	dropout_rates: 0.2
# wandb: 	epochs: 200
# wandb: 	l1: 32
# wandb: 	l2: 16
# wandb: 	learning_rate: 0.013635398995136412
# wandb: 	weights_limit: 0.01911138273089282
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# cat: /sys/module/amdgpu/initstate: No such file or directory
# ERROR:root:Driver not initialized (amdgpu not found in modules)
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/home/t.afanasyeva/wandb/run-20231106_164900-1bflri29</code>
# Syncing run <strong><a href='https://wandb.ai/afanasyeva-team/NN-MATseq/runs/1bflri29' target="_blank">polished-sweep-1</a></strong> to <a href='https://wandb.ai/afanasyeva-team/NN-MATseq' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/afanasyeva-team/NN-MATseq/sweeps/fnhp0fsv' target="_blank">https://wandb.ai/afanasyeva-team/NN-MATseq/sweeps/fnhp0fsv</a>
#  View project at <a href='https://wandb.ai/afanasyeva-team/NN-MATseq' target="_blank">https://wandb.ai/afanasyeva-team/NN-MATseq</a>
#  View sweep at <a href='https://wandb.ai/afanasyeva-team/NN-MATseq/sweeps/fnhp0fsv' target="_blank">https://wandb.ai/afanasyeva-team/NN-MATseq/sweeps/fnhp0fsv</a>
#  View run at <a href='https://wandb.ai/afanasyeva-team/NN-MATseq/runs/1bflri29' target="_blank">https://wandb.ai/afanasyeva-team/NN-MATseq/runs/1bflri29</a>
# wandb: WARNING The save_model argument by default saves the model in the HDF5 format that cannot save custom objects like subclassed models and custom layers. This behavior will be deprecated in a future release in favor of the SavedModel format. Meanwhile, the HDF5 model is saved as W&B files and the SavedModel as W&B Artifacts.
# Epoch 1/200
# 1/6 [====>.........................] - ETA: 7s - loss: 5.1857 - accuracy: 0.0833 - auc: 0.4757
# Epoch 1: loss improved from inf to 5.17378, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 3s 213ms/step - loss: 5.1738 - accuracy: 0.1406 - auc: 0.5035
# Epoch 2/200
# 1/6 [====>.........................] - ETA: 0s - loss: 4.6765 - accuracy: 0.2500 - auc: 0.6693
# Epoch 2: loss improved from 5.17378 to 4.65156, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 133ms/step - loss: 4.6516 - accuracy: 0.2031 - auc: 0.6270
# Epoch 3/200
# 1/6 [====>.........................] - ETA: 0s - loss: 4.6750 - accuracy: 0.2500 - auc: 0.6328
# Epoch 3: loss improved from 4.65156 to 4.00431, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 132ms/step - loss: 4.0043 - accuracy: 0.2969 - auc: 0.7073
# Epoch 4/200
# 1/6 [====>.........................] - ETA: 0s - loss: 3.8323 - accuracy: 0.2500 - auc: 0.6645
# Epoch 4: loss improved from 4.00431 to 3.38651, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 133ms/step - loss: 3.3865 - accuracy: 0.4062 - auc: 0.7548
# Epoch 5/200
# 1/6 [====>.........................] - ETA: 0s - loss: 3.3254 - accuracy: 0.4167 - auc: 0.7387
# Epoch 5: loss improved from 3.38651 to 3.09519, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 133ms/step - loss: 3.0952 - accuracy: 0.3750 - auc: 0.7730
# Epoch 6/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.7603 - accuracy: 0.3333 - auc: 0.8194
# Epoch 6: loss improved from 3.09519 to 2.69359, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 134ms/step - loss: 2.6936 - accuracy: 0.4219 - auc: 0.8148
# Epoch 7/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.7699 - accuracy: 0.3333 - auc: 0.7691
# Epoch 7: loss improved from 2.69359 to 2.51958, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 133ms/step - loss: 2.5196 - accuracy: 0.4531 - auc: 0.8303
# Epoch 8/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.2501 - accuracy: 0.5833 - auc: 0.8863
# Epoch 8: loss improved from 2.51958 to 2.29422, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 193ms/step - loss: 2.2942 - accuracy: 0.4688 - auc: 0.8711
# Epoch 9/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.8314 - accuracy: 0.2500 - auc: 0.6567
# Epoch 9: loss did not improve from 2.29422
# 6/6 [==============================] - 0s 6ms/step - loss: 2.2974 - accuracy: 0.4531 - auc: 0.8399
# Epoch 10/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.2273 - accuracy: 0.4167 - auc: 0.8620
# Epoch 10: loss improved from 2.29422 to 2.11105, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 132ms/step - loss: 2.1110 - accuracy: 0.4688 - auc: 0.8680
# Epoch 11/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8453 - accuracy: 0.6667 - auc: 0.9371
# Epoch 11: loss improved from 2.11105 to 2.05277, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 132ms/step - loss: 2.0528 - accuracy: 0.5312 - auc: 0.8729
# Epoch 12/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6303 - accuracy: 0.6667 - auc: 0.9575
# Epoch 12: loss improved from 2.05277 to 1.87643, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 132ms/step - loss: 1.8764 - accuracy: 0.5469 - auc: 0.8940
# Epoch 13/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.1858 - accuracy: 0.3333 - auc: 0.8377
# Epoch 13: loss did not improve from 1.87643
# 6/6 [==============================] - 0s 6ms/step - loss: 1.9734 - accuracy: 0.4531 - auc: 0.8681
# Epoch 14/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.4658 - accuracy: 0.1667 - auc: 0.7270
# Epoch 14: loss improved from 1.87643 to 1.85483, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 134ms/step - loss: 1.8548 - accuracy: 0.5625 - auc: 0.8885
# Epoch 15/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5740 - accuracy: 0.7500 - auc: 0.9579
# Epoch 15: loss did not improve from 1.85483
# 6/6 [==============================] - 0s 6ms/step - loss: 2.0268 - accuracy: 0.5312 - auc: 0.8471
# Epoch 16/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7579 - accuracy: 0.4167 - auc: 0.8819
# Epoch 16: loss did not improve from 1.85483
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9472 - accuracy: 0.4062 - auc: 0.8620
# Epoch 17/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.3014 - accuracy: 0.1667 - auc: 0.7721
# Epoch 17: loss did not improve from 1.85483
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9403 - accuracy: 0.5156 - auc: 0.8668
# Epoch 18/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.1526 - accuracy: 0.3333 - auc: 0.7938
# Epoch 18: loss improved from 1.85483 to 1.82143, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 132ms/step - loss: 1.8214 - accuracy: 0.5000 - auc: 0.8846
# Epoch 19/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.9536 - accuracy: 0.3333 - auc: 0.8542
# Epoch 19: loss did not improve from 1.82143
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8288 - accuracy: 0.5000 - auc: 0.8768
# Epoch 20/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7045 - accuracy: 0.5833 - auc: 0.9036
# Epoch 20: loss improved from 1.82143 to 1.73146, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 132ms/step - loss: 1.7315 - accuracy: 0.5312 - auc: 0.8907
# Epoch 21/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8546 - accuracy: 0.4167 - auc: 0.8997
# Epoch 21: loss did not improve from 1.73146
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7379 - accuracy: 0.5312 - auc: 0.9032
# Epoch 22/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0497 - accuracy: 0.4167 - auc: 0.8416
# Epoch 22: loss improved from 1.73146 to 1.70476, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 202ms/step - loss: 1.7048 - accuracy: 0.5469 - auc: 0.9052
# Epoch 23/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4140 - accuracy: 0.6667 - auc: 0.9449
# Epoch 23: loss improved from 1.70476 to 1.54143, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 133ms/step - loss: 1.5414 - accuracy: 0.6875 - auc: 0.9373
# Epoch 24/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7342 - accuracy: 0.5000 - auc: 0.8685
# Epoch 24: loss did not improve from 1.54143
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8335 - accuracy: 0.5781 - auc: 0.8750
# Epoch 25/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6897 - accuracy: 0.5000 - auc: 0.9293
# Epoch 25: loss did not improve from 1.54143
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6360 - accuracy: 0.6250 - auc: 0.9248
# Epoch 26/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4559 - accuracy: 0.6667 - auc: 0.9696
# Epoch 26: loss did not improve from 1.54143
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6844 - accuracy: 0.6094 - auc: 0.9147
# Epoch 27/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5129 - accuracy: 0.5833 - auc: 0.9523
# Epoch 27: loss did not improve from 1.54143
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6350 - accuracy: 0.5938 - auc: 0.9340
# Epoch 28/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.1810 - accuracy: 0.3333 - auc: 0.7969
# Epoch 28: loss did not improve from 1.54143
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6434 - accuracy: 0.5781 - auc: 0.9188
# Epoch 29/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.3593 - accuracy: 0.8333 - auc: 0.9579
# Epoch 29: loss did not improve from 1.54143
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6783 - accuracy: 0.5781 - auc: 0.9029
# Epoch 30/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7788 - accuracy: 0.5000 - auc: 0.9041
# Epoch 30: loss did not improve from 1.54143
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6658 - accuracy: 0.4844 - auc: 0.9102
# Epoch 31/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0112 - accuracy: 0.5000 - auc: 0.8286
# Epoch 31: loss did not improve from 1.54143
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8149 - accuracy: 0.5312 - auc: 0.8846
# Epoch 32/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.3910 - accuracy: 0.7500 - auc: 0.9761
# Epoch 32: loss did not improve from 1.54143
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8235 - accuracy: 0.5312 - auc: 0.8882
# Epoch 33/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6648 - accuracy: 0.6667 - auc: 0.9115
# Epoch 33: loss did not improve from 1.54143
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8028 - accuracy: 0.5625 - auc: 0.8877
# Epoch 34/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4818 - accuracy: 0.5833 - auc: 0.9510
# Epoch 34: loss did not improve from 1.54143
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6509 - accuracy: 0.5625 - auc: 0.9207
# Epoch 35/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2029 - accuracy: 0.7500 - auc: 0.9809
# Epoch 35: loss improved from 1.54143 to 1.51454, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 133ms/step - loss: 1.5145 - accuracy: 0.6562 - auc: 0.9460
# Epoch 36/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5208 - accuracy: 0.5000 - auc: 0.9549
# Epoch 36: loss did not improve from 1.51454
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6193 - accuracy: 0.5312 - auc: 0.9324
# Epoch 37/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7332 - accuracy: 0.5000 - auc: 0.8928
# Epoch 37: loss did not improve from 1.51454
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8260 - accuracy: 0.4688 - auc: 0.8844
# Epoch 38/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.9127 - accuracy: 0.6667 - auc: 0.8503
# Epoch 38: loss did not improve from 1.51454
# 6/6 [==============================] - 0s 7ms/step - loss: 1.6465 - accuracy: 0.5938 - auc: 0.9011
# Epoch 39/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6420 - accuracy: 0.5000 - auc: 0.8924
# Epoch 39: loss did not improve from 1.51454
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5892 - accuracy: 0.5781 - auc: 0.9220
# Epoch 40/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6431 - accuracy: 0.5833 - auc: 0.9197
# Epoch 40: loss did not improve from 1.51454
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6288 - accuracy: 0.5625 - auc: 0.9170
# Epoch 41/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6576 - accuracy: 0.5000 - auc: 0.8984
# Epoch 41: loss did not improve from 1.51454
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5606 - accuracy: 0.5938 - auc: 0.9286
# Epoch 42/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7867 - accuracy: 0.5000 - auc: 0.8889
# Epoch 42: loss did not improve from 1.51454
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5601 - accuracy: 0.5938 - auc: 0.9230
# Epoch 43/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4092 - accuracy: 0.7500 - auc: 0.9323
# Epoch 43: loss improved from 1.51454 to 1.50503, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 132ms/step - loss: 1.5050 - accuracy: 0.5938 - auc: 0.9322
# Epoch 44/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6857 - accuracy: 0.5000 - auc: 0.9093
# Epoch 44: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6590 - accuracy: 0.5312 - auc: 0.9133
# Epoch 45/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5671 - accuracy: 0.5833 - auc: 0.9345
# Epoch 45: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6375 - accuracy: 0.6250 - auc: 0.9218
# Epoch 46/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4201 - accuracy: 0.5833 - auc: 0.9566
# Epoch 46: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8460 - accuracy: 0.4844 - auc: 0.8886
# Epoch 47/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0977 - accuracy: 0.4167 - auc: 0.8403
# Epoch 47: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7085 - accuracy: 0.5469 - auc: 0.9093
# Epoch 48/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4493 - accuracy: 0.7500 - auc: 0.9596
# Epoch 48: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6119 - accuracy: 0.5625 - auc: 0.9243
# Epoch 49/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7416 - accuracy: 0.5000 - auc: 0.8967
# Epoch 49: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7915 - accuracy: 0.5469 - auc: 0.8934
# Epoch 50/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7019 - accuracy: 0.6667 - auc: 0.9154
# Epoch 50: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7414 - accuracy: 0.5469 - auc: 0.9013
# Epoch 51/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8635 - accuracy: 0.5000 - auc: 0.8581
# Epoch 51: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5800 - accuracy: 0.5938 - auc: 0.9306
# Epoch 52/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5899 - accuracy: 0.8333 - auc: 0.9362
# Epoch 52: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6012 - accuracy: 0.7031 - auc: 0.9266
# Epoch 53/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2764 - accuracy: 0.6667 - auc: 0.9766
# Epoch 53: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7273 - accuracy: 0.5938 - auc: 0.9100
# Epoch 54/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8734 - accuracy: 0.5833 - auc: 0.8885
# Epoch 54: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 7ms/step - loss: 1.7537 - accuracy: 0.5469 - auc: 0.9044
# Epoch 55/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8469 - accuracy: 0.4167 - auc: 0.8685
# Epoch 55: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8676 - accuracy: 0.5156 - auc: 0.8766
# Epoch 56/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.3665 - accuracy: 0.8333 - auc: 0.9540
# Epoch 56: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7404 - accuracy: 0.5938 - auc: 0.9106
# Epoch 57/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7607 - accuracy: 0.6667 - auc: 0.9089
# Epoch 57: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7284 - accuracy: 0.6250 - auc: 0.9107
# Epoch 58/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5987 - accuracy: 0.5833 - auc: 0.9392
# Epoch 58: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7041 - accuracy: 0.6250 - auc: 0.9171
# Epoch 59/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2603 - accuracy: 0.7500 - auc: 0.9727
# Epoch 59: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5509 - accuracy: 0.6094 - auc: 0.9411
# Epoch 60/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5276 - accuracy: 0.6667 - auc: 0.9470
# Epoch 60: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 7ms/step - loss: 1.5258 - accuracy: 0.5938 - auc: 0.9386
# Epoch 61/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.9777 - accuracy: 0.5000 - auc: 0.8520
# Epoch 61: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5514 - accuracy: 0.6094 - auc: 0.9291
# Epoch 62/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6646 - accuracy: 0.5000 - auc: 0.9110
# Epoch 62: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5738 - accuracy: 0.6094 - auc: 0.9258
# Epoch 63/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8754 - accuracy: 0.5000 - auc: 0.8698
# Epoch 63: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7459 - accuracy: 0.5156 - auc: 0.9047
# Epoch 64/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4776 - accuracy: 0.5833 - auc: 0.9449
# Epoch 64: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5562 - accuracy: 0.6562 - auc: 0.9329
# Epoch 65/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.9632 - accuracy: 0.5000 - auc: 0.8607
# Epoch 65: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6773 - accuracy: 0.5625 - auc: 0.9166
# Epoch 66/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.9259 - accuracy: 0.6667 - auc: 0.8720
# Epoch 66: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6871 - accuracy: 0.6250 - auc: 0.9184
# Epoch 67/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7415 - accuracy: 0.5833 - auc: 0.9089
# Epoch 67: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7050 - accuracy: 0.5625 - auc: 0.9126
# Epoch 68/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7709 - accuracy: 0.6667 - auc: 0.8989
# Epoch 68: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5653 - accuracy: 0.6406 - auc: 0.9343
# Epoch 69/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7008 - accuracy: 0.5000 - auc: 0.9132
# Epoch 69: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6790 - accuracy: 0.5469 - auc: 0.9163
# Epoch 70/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7431 - accuracy: 0.4167 - auc: 0.9006
# Epoch 70: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5676 - accuracy: 0.5938 - auc: 0.9252
# Epoch 71/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5177 - accuracy: 0.6667 - auc: 0.9323
# Epoch 71: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5480 - accuracy: 0.6250 - auc: 0.9289
# Epoch 72/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5130 - accuracy: 0.6667 - auc: 0.9327
# Epoch 72: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6002 - accuracy: 0.5625 - auc: 0.9225
# Epoch 73/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.9412 - accuracy: 0.3333 - auc: 0.8598
# Epoch 73: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7123 - accuracy: 0.5156 - auc: 0.8969
# Epoch 74/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7812 - accuracy: 0.5000 - auc: 0.8733
# Epoch 74: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5767 - accuracy: 0.5781 - auc: 0.9193
# Epoch 75/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8667 - accuracy: 0.5833 - auc: 0.8793
# Epoch 75: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7152 - accuracy: 0.5000 - auc: 0.9049
# Epoch 76/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.3556 - accuracy: 0.6667 - auc: 0.9583
# Epoch 76: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5179 - accuracy: 0.6250 - auc: 0.9407
# Epoch 77/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5547 - accuracy: 0.5833 - auc: 0.9266
# Epoch 77: loss did not improve from 1.50503
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7002 - accuracy: 0.5312 - auc: 0.9107
# Epoch 78/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6433 - accuracy: 0.5833 - auc: 0.9240
# Epoch 78: loss improved from 1.50503 to 1.37038, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 139ms/step - loss: 1.3704 - accuracy: 0.6875 - auc: 0.9617
# Epoch 79/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4093 - accuracy: 0.5833 - auc: 0.9635
# Epoch 79: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5030 - accuracy: 0.5781 - auc: 0.9442
# Epoch 80/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6019 - accuracy: 0.6667 - auc: 0.9158
# Epoch 80: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 7ms/step - loss: 1.5651 - accuracy: 0.6250 - auc: 0.9258
# Epoch 81/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0141 - accuracy: 0.4167 - auc: 0.8286
# Epoch 81: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6895 - accuracy: 0.5625 - auc: 0.9069
# Epoch 82/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7761 - accuracy: 0.5000 - auc: 0.8906
# Epoch 82: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6229 - accuracy: 0.5625 - auc: 0.9204
# Epoch 83/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.1468 - accuracy: 0.4167 - auc: 0.8108
# Epoch 83: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6451 - accuracy: 0.5625 - auc: 0.9137
# Epoch 84/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4423 - accuracy: 0.6667 - auc: 0.9436
# Epoch 84: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7334 - accuracy: 0.5781 - auc: 0.8965
# Epoch 85/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8306 - accuracy: 0.3333 - auc: 0.8841
# Epoch 85: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7540 - accuracy: 0.5000 - auc: 0.8923
# Epoch 86/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.2452 - accuracy: 0.2500 - auc: 0.8160
# Epoch 86: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7464 - accuracy: 0.4531 - auc: 0.8963
# Epoch 87/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.3554 - accuracy: 0.7500 - auc: 0.9562
# Epoch 87: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6416 - accuracy: 0.5469 - auc: 0.9116
# Epoch 88/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6919 - accuracy: 0.5833 - auc: 0.9002
# Epoch 88: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5260 - accuracy: 0.6250 - auc: 0.9324
# Epoch 89/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5781 - accuracy: 0.5833 - auc: 0.9570
# Epoch 89: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6395 - accuracy: 0.5625 - auc: 0.9262
# Epoch 90/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4044 - accuracy: 0.5833 - auc: 0.9583
# Epoch 90: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6888 - accuracy: 0.6250 - auc: 0.9182
# Epoch 91/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2150 - accuracy: 0.8333 - auc: 0.9792
# Epoch 91: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6872 - accuracy: 0.6562 - auc: 0.9244
# Epoch 92/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.2887 - accuracy: 0.3333 - auc: 0.8516
# Epoch 92: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.9337 - accuracy: 0.5156 - auc: 0.9027
# Epoch 93/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8620 - accuracy: 0.5000 - auc: 0.9197
# Epoch 93: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 7ms/step - loss: 2.1961 - accuracy: 0.4375 - auc: 0.8708
# Epoch 94/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.8792 - accuracy: 0.3333 - auc: 0.7869
# Epoch 94: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 2.2392 - accuracy: 0.5000 - auc: 0.8614
# Epoch 95/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8204 - accuracy: 0.5000 - auc: 0.9219
# Epoch 95: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8307 - accuracy: 0.5938 - auc: 0.9160
# Epoch 96/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0193 - accuracy: 0.5833 - auc: 0.8876
# Epoch 96: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8987 - accuracy: 0.4688 - auc: 0.8971
# Epoch 97/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5691 - accuracy: 0.7500 - auc: 0.9405
# Epoch 97: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6981 - accuracy: 0.6250 - auc: 0.9218
# Epoch 98/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0418 - accuracy: 0.4167 - auc: 0.8598
# Epoch 98: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8373 - accuracy: 0.5156 - auc: 0.9010
# Epoch 99/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6461 - accuracy: 0.6667 - auc: 0.9301
# Epoch 99: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7012 - accuracy: 0.5938 - auc: 0.9233
# Epoch 100/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4098 - accuracy: 0.5833 - auc: 0.9622
# Epoch 100: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7806 - accuracy: 0.5156 - auc: 0.9003
# Epoch 101/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5899 - accuracy: 0.5833 - auc: 0.9440
# Epoch 101: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6072 - accuracy: 0.5469 - auc: 0.9339
# Epoch 102/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.3068 - accuracy: 0.5000 - auc: 0.8494
# Epoch 102: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8067 - accuracy: 0.5312 - auc: 0.9086
# Epoch 103/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5741 - accuracy: 0.6667 - auc: 0.9332
# Epoch 103: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7534 - accuracy: 0.5625 - auc: 0.9140
# Epoch 104/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.9365 - accuracy: 0.5000 - auc: 0.8646
# Epoch 104: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6184 - accuracy: 0.6094 - auc: 0.9272
# Epoch 105/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7645 - accuracy: 0.4167 - auc: 0.9058
# Epoch 105: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6367 - accuracy: 0.5781 - auc: 0.9221
# Epoch 106/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5173 - accuracy: 0.5833 - auc: 0.9306
# Epoch 106: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4851 - accuracy: 0.6250 - auc: 0.9385
# Epoch 107/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2731 - accuracy: 0.6667 - auc: 0.9683
# Epoch 107: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5296 - accuracy: 0.6250 - auc: 0.9261
# Epoch 108/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6485 - accuracy: 0.5000 - auc: 0.9219
# Epoch 108: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 7ms/step - loss: 1.6823 - accuracy: 0.5781 - auc: 0.9189
# Epoch 109/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5667 - accuracy: 0.5000 - auc: 0.9275
# Epoch 109: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7025 - accuracy: 0.5312 - auc: 0.9142
# Epoch 110/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.3037 - accuracy: 0.2500 - auc: 0.7817
# Epoch 110: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6255 - accuracy: 0.5625 - auc: 0.9297
# Epoch 111/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0684 - accuracy: 0.4167 - auc: 0.8433
# Epoch 111: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7902 - accuracy: 0.5000 - auc: 0.9015
# Epoch 112/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5249 - accuracy: 0.5833 - auc: 0.9527
# Epoch 112: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6608 - accuracy: 0.5625 - auc: 0.9188
# Epoch 113/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6579 - accuracy: 0.5000 - auc: 0.9258
# Epoch 113: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 7ms/step - loss: 1.6999 - accuracy: 0.5625 - auc: 0.9127
# Epoch 114/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.1487 - accuracy: 0.7500 - auc: 0.9796
# Epoch 114: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5564 - accuracy: 0.5938 - auc: 0.9354
# Epoch 115/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0156 - accuracy: 0.5000 - auc: 0.8967
# Epoch 115: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7981 - accuracy: 0.5469 - auc: 0.9025
# Epoch 116/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4175 - accuracy: 0.7500 - auc: 0.9531
# Epoch 116: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6287 - accuracy: 0.6094 - auc: 0.9262
# Epoch 117/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.3940 - accuracy: 0.7500 - auc: 0.9536
# Epoch 117: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6985 - accuracy: 0.5781 - auc: 0.9120
# Epoch 118/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0466 - accuracy: 0.2500 - auc: 0.8620
# Epoch 118: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6958 - accuracy: 0.5156 - auc: 0.9152
# Epoch 119/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4340 - accuracy: 0.8333 - auc: 0.9674
# Epoch 119: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6545 - accuracy: 0.5469 - auc: 0.9239
# Epoch 120/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0079 - accuracy: 0.4167 - auc: 0.8646
# Epoch 120: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7020 - accuracy: 0.5625 - auc: 0.9171
# Epoch 121/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.2325 - accuracy: 0.5000 - auc: 0.8299
# Epoch 121: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6697 - accuracy: 0.6719 - auc: 0.9199
# Epoch 122/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4690 - accuracy: 0.7500 - auc: 0.9692
# Epoch 122: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6997 - accuracy: 0.5625 - auc: 0.9237
# Epoch 123/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4677 - accuracy: 0.7500 - auc: 0.9566
# Epoch 123: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7060 - accuracy: 0.5625 - auc: 0.9162
# Epoch 124/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0302 - accuracy: 0.4167 - auc: 0.8524
# Epoch 124: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7106 - accuracy: 0.5781 - auc: 0.9102
# Epoch 125/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5869 - accuracy: 0.7500 - auc: 0.9388
# Epoch 125: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 5ms/step - loss: 1.5664 - accuracy: 0.6250 - auc: 0.9255
# Epoch 126/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4883 - accuracy: 0.5833 - auc: 0.9345
# Epoch 126: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 5ms/step - loss: 1.5459 - accuracy: 0.5625 - auc: 0.9315
# Epoch 127/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6206 - accuracy: 0.5833 - auc: 0.9288
# Epoch 127: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4024 - accuracy: 0.6562 - auc: 0.9560
# Epoch 128/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4958 - accuracy: 0.5833 - auc: 0.9518
# Epoch 128: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4180 - accuracy: 0.6719 - auc: 0.9487
# Epoch 129/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2820 - accuracy: 0.8333 - auc: 0.9818
# Epoch 129: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5169 - accuracy: 0.5938 - auc: 0.9363
# Epoch 130/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4840 - accuracy: 0.5833 - auc: 0.9275
# Epoch 130: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4532 - accuracy: 0.6250 - auc: 0.9396
# Epoch 131/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7127 - accuracy: 0.5000 - auc: 0.9049
# Epoch 131: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5360 - accuracy: 0.6250 - auc: 0.9277
# Epoch 132/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5015 - accuracy: 0.5833 - auc: 0.9319
# Epoch 132: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5728 - accuracy: 0.6094 - auc: 0.9261
# Epoch 133/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.3124 - accuracy: 0.5833 - auc: 0.9605
# Epoch 133: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4554 - accuracy: 0.5625 - auc: 0.9388
# Epoch 134/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.1677 - accuracy: 0.8333 - auc: 0.9861
# Epoch 134: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4239 - accuracy: 0.6250 - auc: 0.9446
# Epoch 135/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5318 - accuracy: 0.5833 - auc: 0.9358
# Epoch 135: loss did not improve from 1.37038
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5011 - accuracy: 0.6719 - auc: 0.9345
# Epoch 136/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.0969 - accuracy: 0.7500 - auc: 0.9852
# Epoch 136: loss improved from 1.37038 to 1.36987, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 137ms/step - loss: 1.3699 - accuracy: 0.6719 - auc: 0.9572
# Epoch 137/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8326 - accuracy: 0.5000 - auc: 0.8707
# Epoch 137: loss did not improve from 1.36987
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5634 - accuracy: 0.5781 - auc: 0.9259
# Epoch 138/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.1773 - accuracy: 0.8333 - auc: 0.9896
# Epoch 138: loss improved from 1.36987 to 1.29995, saving model to /home/t.afanasyeva/MATseq/notebooks/model_zoo
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# INFO:tensorflow:Assets written to: /home/t.afanasyeva/MATseq/notebooks/model_zoo/assets
# 6/6 [==============================] - 1s 138ms/step - loss: 1.2999 - accuracy: 0.6562 - auc: 0.9693
# Epoch 139/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7032 - accuracy: 0.4167 - auc: 0.9119
# Epoch 139: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4489 - accuracy: 0.5781 - auc: 0.9456
# Epoch 140/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2821 - accuracy: 0.7500 - auc: 0.9614
# Epoch 140: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4314 - accuracy: 0.6719 - auc: 0.9489
# Epoch 141/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4336 - accuracy: 0.6667 - auc: 0.9549
# Epoch 141: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4152 - accuracy: 0.6250 - auc: 0.9494
# Epoch 142/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5392 - accuracy: 0.3333 - auc: 0.9297
# Epoch 142: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4372 - accuracy: 0.6250 - auc: 0.9420
# Epoch 143/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0636 - accuracy: 0.6667 - auc: 0.8672
# Epoch 143: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7871 - accuracy: 0.6094 - auc: 0.9054
# Epoch 144/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.9778 - accuracy: 0.3333 - auc: 0.8646
# Epoch 144: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8948 - accuracy: 0.5000 - auc: 0.8924
# Epoch 145/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0003 - accuracy: 0.5000 - auc: 0.8650
# Epoch 145: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7472 - accuracy: 0.5625 - auc: 0.9169
# Epoch 146/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6509 - accuracy: 0.5000 - auc: 0.9323
# Epoch 146: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6393 - accuracy: 0.5469 - auc: 0.9368
# Epoch 147/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5261 - accuracy: 0.6667 - auc: 0.9527
# Epoch 147: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5035 - accuracy: 0.6719 - auc: 0.9454
# Epoch 148/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.1593 - accuracy: 0.7500 - auc: 0.9835
# Epoch 148: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7194 - accuracy: 0.5000 - auc: 0.9130
# Epoch 149/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7365 - accuracy: 0.5000 - auc: 0.9006
# Epoch 149: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4941 - accuracy: 0.6562 - auc: 0.9399
# Epoch 150/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4201 - accuracy: 0.6667 - auc: 0.9618
# Epoch 150: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5031 - accuracy: 0.5938 - auc: 0.9417
# Epoch 151/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5236 - accuracy: 0.5833 - auc: 0.9497
# Epoch 151: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5604 - accuracy: 0.6094 - auc: 0.9330
# Epoch 152/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5729 - accuracy: 0.4167 - auc: 0.9349
# Epoch 152: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4662 - accuracy: 0.5781 - auc: 0.9429
# Epoch 153/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5105 - accuracy: 0.6667 - auc: 0.9436
# Epoch 153: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4327 - accuracy: 0.5781 - auc: 0.9472
# Epoch 154/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5340 - accuracy: 0.7500 - auc: 0.9327
# Epoch 154: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6206 - accuracy: 0.7031 - auc: 0.9204
# Epoch 155/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2442 - accuracy: 0.8333 - auc: 0.9640
# Epoch 155: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4286 - accuracy: 0.6719 - auc: 0.9469
# Epoch 156/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6245 - accuracy: 0.5833 - auc: 0.9193
# Epoch 156: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 5ms/step - loss: 1.7067 - accuracy: 0.5625 - auc: 0.9038
# Epoch 157/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8820 - accuracy: 0.4167 - auc: 0.8746
# Epoch 157: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5889 - accuracy: 0.5000 - auc: 0.9263
# Epoch 158/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.3892 - accuracy: 0.8333 - auc: 0.9531
# Epoch 158: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7850 - accuracy: 0.5625 - auc: 0.8928
# Epoch 159/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6644 - accuracy: 0.6667 - auc: 0.9149
# Epoch 159: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8152 - accuracy: 0.6094 - auc: 0.8906
# Epoch 160/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5501 - accuracy: 0.6667 - auc: 0.9345
# Epoch 160: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4722 - accuracy: 0.6719 - auc: 0.9493
# Epoch 161/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.3992 - accuracy: 0.6667 - auc: 0.9575
# Epoch 161: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6214 - accuracy: 0.6250 - auc: 0.9328
# Epoch 162/200
# 1/6 [====>.........................] - ETA: 0s - loss: 2.5496 - accuracy: 0.3333 - auc: 0.7804
# Epoch 162: loss did not improve from 1.29995
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7762 - accuracy: 0.5469 - auc: 0.9093
# Epoch 163/200
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8783 - accuracy: 0.5833 - auc: 0.8958
# ...
# Epoch 172/320
# 1/6 [====>.........................] - ETA: 0s - loss: 2.1582 - accuracy: 0.5833 - auc: 0.8746
# Epoch 172: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 2.1180 - accuracy: 0.4844 - auc: 0.8794
# Epoch 173/320
# 1/6 [====>.........................] - ETA: 0s - loss: 2.3962 - accuracy: 0.4167 - auc: 0.8333
# Epoch 173: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 2.1579 - accuracy: 0.4688 - auc: 0.8711
# Epoch 174/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.9072 - accuracy: 0.3333 - auc: 0.9067
# Epoch 174: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 2.1642 - accuracy: 0.4062 - auc: 0.8692
# Epoch 175/320
# 1/6 [====>.........................] - ETA: 0s - loss: 2.4843 - accuracy: 0.2500 - auc: 0.8012
# Epoch 175: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 2.2672 - accuracy: 0.4062 - auc: 0.8527
# Epoch 176/320
# 1/6 [====>.........................] - ETA: 0s - loss: 2.5283 - accuracy: 0.3333 - auc: 0.8225
# Epoch 176: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 8ms/step - loss: 2.5186 - accuracy: 0.4688 - auc: 0.8435
# Epoch 177/320
# 1/6 [====>.........................] - ETA: 0s - loss: 2.5223 - accuracy: 0.3333 - auc: 0.8277
# Epoch 177: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 2.4898 - accuracy: 0.5156 - auc: 0.8518
# Epoch 178/320
# 1/6 [====>.........................] - ETA: 0s - loss: 2.1061 - accuracy: 0.5000 - auc: 0.9023
# Epoch 178: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 2.3647 - accuracy: 0.5156 - auc: 0.8842
# Epoch 179/320
# 1/6 [====>.........................] - ETA: 0s - loss: 2.5878 - accuracy: 0.5833 - auc: 0.8151
# Epoch 179: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 2.0810 - accuracy: 0.5938 - auc: 0.8875
# Epoch 180/320
# 1/6 [====>.........................] - ETA: 0s - loss: 2.2827 - accuracy: 0.2500 - auc: 0.8789
# Epoch 180: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 2.2993 - accuracy: 0.4688 - auc: 0.8684
# Epoch 181/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.9004 - accuracy: 0.6667 - auc: 0.8911
# Epoch 181: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 7ms/step - loss: 2.2906 - accuracy: 0.5312 - auc: 0.8545
# Epoch 182/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7870 - accuracy: 0.7500 - auc: 0.9293
# Epoch 182: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 2.2733 - accuracy: 0.4844 - auc: 0.8663
# Epoch 183/320
# 1/6 [====>.........................] - ETA: 0s - loss: 2.6510 - accuracy: 0.1667 - auc: 0.7708
# Epoch 183: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 2.1417 - accuracy: 0.4375 - auc: 0.8764
# Epoch 184/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.9097 - accuracy: 0.5000 - auc: 0.9106
# Epoch 184: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 2.1210 - accuracy: 0.5000 - auc: 0.8824
# Epoch 185/320
# 1/6 [====>.........................] - ETA: 0s - loss: 2.1218 - accuracy: 0.7500 - auc: 0.8806
# Epoch 185: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.9482 - accuracy: 0.6562 - auc: 0.9004
# Epoch 186/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7430 - accuracy: 0.7500 - auc: 0.9275
# Epoch 186: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 2.0534 - accuracy: 0.5000 - auc: 0.8923
# Epoch 187/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7864 - accuracy: 0.4167 - auc: 0.9180
# Epoch 187: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 2.0341 - accuracy: 0.4062 - auc: 0.8679
# Epoch 188/320
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0323 - accuracy: 0.5833 - auc: 0.8403
# Epoch 188: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 2.0059 - accuracy: 0.4844 - auc: 0.8643
# Epoch 189/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6312 - accuracy: 0.5000 - auc: 0.9310
# Epoch 189: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7555 - accuracy: 0.5781 - auc: 0.9150
# Epoch 190/320
# 1/6 [====>.........................] - ETA: 0s - loss: 2.2155 - accuracy: 0.3333 - auc: 0.8355
# Epoch 190: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.9099 - accuracy: 0.5156 - auc: 0.8993
# Epoch 191/320
# 1/6 [====>.........................] - ETA: 0s - loss: 2.1474 - accuracy: 0.3333 - auc: 0.8485
# Epoch 191: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6960 - accuracy: 0.5625 - auc: 0.9187
# Epoch 192/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6205 - accuracy: 0.6667 - auc: 0.9293
# Epoch 192: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 7ms/step - loss: 1.5548 - accuracy: 0.5469 - auc: 0.9350
# Epoch 193/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7449 - accuracy: 0.5000 - auc: 0.8980
# Epoch 193: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7747 - accuracy: 0.5625 - auc: 0.8926
# Epoch 194/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4274 - accuracy: 0.6667 - auc: 0.9605
# Epoch 194: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5743 - accuracy: 0.6406 - auc: 0.9210
# Epoch 195/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5199 - accuracy: 0.5833 - auc: 0.9314
# Epoch 195: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8069 - accuracy: 0.5156 - auc: 0.8852
# Epoch 196/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8602 - accuracy: 0.4167 - auc: 0.8772
# Epoch 196: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7315 - accuracy: 0.4844 - auc: 0.8955
# Epoch 197/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2140 - accuracy: 0.8333 - auc: 0.9740
# Epoch 197: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5827 - accuracy: 0.5938 - auc: 0.9249
# Epoch 198/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6724 - accuracy: 0.5833 - auc: 0.9128
# Epoch 198: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 7ms/step - loss: 1.4879 - accuracy: 0.5938 - auc: 0.9352
# Epoch 199/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6112 - accuracy: 0.4167 - auc: 0.9240
# Epoch 199: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4830 - accuracy: 0.5938 - auc: 0.9366
# Epoch 200/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5667 - accuracy: 0.6667 - auc: 0.9219
# Epoch 200: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5884 - accuracy: 0.5312 - auc: 0.9167
# Epoch 201/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6773 - accuracy: 0.5833 - auc: 0.8937
# Epoch 201: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4332 - accuracy: 0.6875 - auc: 0.9314
# Epoch 202/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6085 - accuracy: 0.4167 - auc: 0.9097
# Epoch 202: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.3833 - accuracy: 0.5781 - auc: 0.9374
# Epoch 203/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.3497 - accuracy: 0.5833 - auc: 0.9466
# Epoch 203: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.4859 - accuracy: 0.6250 - auc: 0.9250
# Epoch 204/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6255 - accuracy: 0.5833 - auc: 0.8997
# Epoch 204: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7940 - accuracy: 0.5938 - auc: 0.8953
# Epoch 205/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8323 - accuracy: 0.4167 - auc: 0.8767
# Epoch 205: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 5ms/step - loss: 2.0408 - accuracy: 0.3906 - auc: 0.8544
# Epoch 206/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8333 - accuracy: 0.5833 - auc: 0.9028
# Epoch 206: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6897 - accuracy: 0.5312 - auc: 0.9128
# Epoch 207/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6110 - accuracy: 0.5833 - auc: 0.9188
# Epoch 207: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 2.0157 - accuracy: 0.4062 - auc: 0.8577
# Epoch 208/320
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0017 - accuracy: 0.2500 - auc: 0.8646
# Epoch 208: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.9017 - accuracy: 0.4531 - auc: 0.8761
# Epoch 209/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2849 - accuracy: 0.7500 - auc: 0.9692
# Epoch 209: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8286 - accuracy: 0.5625 - auc: 0.8922
# Epoch 210/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4220 - accuracy: 0.6667 - auc: 0.9596
# Epoch 210: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.7599 - accuracy: 0.5781 - auc: 0.9077
# Epoch 211/320
# 1/6 [====>.........................] - ETA: 0s - loss: 2.2576 - accuracy: 0.5000 - auc: 0.8342
# Epoch 211: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8262 - accuracy: 0.5312 - auc: 0.9034
# Epoch 212/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4517 - accuracy: 0.7500 - auc: 0.9497
# Epoch 212: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8350 - accuracy: 0.5156 - auc: 0.8974
# Epoch 213/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2901 - accuracy: 0.9167 - auc: 0.9766
# Epoch 213: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.9632 - accuracy: 0.5000 - auc: 0.8753
# Epoch 214/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4489 - accuracy: 0.8333 - auc: 0.9475
# Epoch 214: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8960 - accuracy: 0.5469 - auc: 0.8895
# Epoch 215/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5367 - accuracy: 0.5833 - auc: 0.9388
# Epoch 215: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 2.0242 - accuracy: 0.4688 - auc: 0.8620
# Epoch 216/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5855 - accuracy: 0.5833 - auc: 0.9436
# Epoch 216: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.9384 - accuracy: 0.4688 - auc: 0.8830
# Epoch 217/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.9534 - accuracy: 0.5000 - auc: 0.8811
# Epoch 217: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.8114 - accuracy: 0.5781 - auc: 0.9036
# Epoch 218/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.8351 - accuracy: 0.5000 - auc: 0.9023
# Epoch 218: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6551 - accuracy: 0.5625 - auc: 0.9256
# Epoch 219/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7203 - accuracy: 0.5833 - auc: 0.9210
# Epoch 219: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5826 - accuracy: 0.6406 - auc: 0.9351
# Epoch 220/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.9396 - accuracy: 0.4167 - auc: 0.8542
# Epoch 220: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 6ms/step - loss: 1.6093 - accuracy: 0.5938 - auc: 0.9146
# Epoch 221/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.2235 - accuracy: 0.7500 - auc: 0.9748
# wandb: Ctrl + C detected. Stopping sweep.
# Error in callback <bound method _WandbInit._pause_backend of <wandb.sdk.wandb_init._WandbInit object at 0x7fbd1c9a9150>> (for post_run_cell), with arguments args (<ExecutionResult object at 7fbd241980d0, execution_count=45 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 7fbd24198430, raw_cell="count = 50
# wandb.agent(sweep_id, train, count=coun.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X34sdW50aXRsZWQ%3D> result=None>,),kwargs {}:
#
# Epoch 221: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 10ms/step - loss: 1.4811 - accuracy: 0.6094 - auc: 0.9371
# Epoch 222/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.3024 - accuracy: 0.5833 - auc: 0.9531
# Epoch 222: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 7ms/step - loss: 1.4708 - accuracy: 0.6094 - auc: 0.9352
# Epoch 223/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4992 - accuracy: 0.5000 - auc: 0.9266
# Epoch 223: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 7ms/step - loss: 1.5061 - accuracy: 0.5781 - auc: 0.9285
# Epoch 224/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.4017 - accuracy: 0.5000 - auc: 0.9358
# Epoch 224: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 7ms/step - loss: 1.4401 - accuracy: 0.5781 - auc: 0.9413
# Epoch 225/320
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0724 - accuracy: 0.3333 - auc: 0.8585
# Epoch 225: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 7ms/step - loss: 1.6954 - accuracy: 0.5625 - auc: 0.9029
# Epoch 226/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.3200 - accuracy: 0.7500 - auc: 0.9592
# Epoch 226: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 7ms/step - loss: 1.8208 - accuracy: 0.5625 - auc: 0.8932
# Epoch 227/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.6256 - accuracy: 0.4167 - auc: 0.9058
# Epoch 227: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 7ms/step - loss: 1.9101 - accuracy: 0.4531 - auc: 0.8844
# Epoch 228/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.5738 - accuracy: 0.6667 - auc: 0.9266
# Epoch 228: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 7ms/step - loss: 1.9939 - accuracy: 0.5625 - auc: 0.8727
# Epoch 229/320
# 1/6 [====>.........................] - ETA: 0s - loss: 2.0513 - accuracy: 0.3333 - auc: 0.8681
# Epoch 229: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 7ms/step - loss: 2.0503 - accuracy: 0.3906 - auc: 0.8626
# Epoch 230/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7571 - accuracy: 0.4167 - auc: 0.9219
# Epoch 230: loss did not improve from 1.07285
# 6/6 [==============================] - 0s 7ms/step - loss: 1.9609 - accuracy: 0.4062 - auc: 0.8724
# Epoch 231/320
# 1/6 [====>.........................] - ETA: 0s - loss: 1.7504 - accuracy: 0.4167 - auc: 0.9119
# Epoch 231: loss did not improve from 1.07285
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: _WandbInit._pause_backend() takes 1 positional argument but 2 were given
