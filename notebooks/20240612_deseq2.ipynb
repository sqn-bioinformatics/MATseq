# %% [markdown]
# # DeSeq2 analysis

# %% [markdown]
# 13-12-2024
# Updated

# %%
import os
import pandas as pd
import scanpy as sc
import anndata

from goatools.base import download_go_basic_obo
from goatools.base import gunzip
from goatools.obo_parser import GODag
from goatools.anno.genetogo_reader import Gene2GoReader
from goatools.goea.go_enrichment_ns import GOEnrichmentStudyNS

from genes_ncbi_homo_sapiens_proteincoding import GENEID2NT as GeneID2nt_hs

from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats
from pydeseq2.default_inference import DefaultInference

from pathlib import Path
from datetime import datetime

from adjustText import adjust_text
from typing import Union
from anndata import AnnData

# %%
import seaborn as sns
import textwrap
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.figure as figure
from matplotlib.patches import Patch

rc = {"figure.dpi": 150}
sns.set_theme(
    context="notebook",
    style="white",
    palette="deep",
    font="sans-serif",
    font_scale=4,
    color_codes=True,
    rc=rc,
)

# %% [markdown]
# pydeseq2 is not supporting numpy.v2, thereby important to keep downgraded numpy

# %%
import numpy as np

print(np.__version__)

# %%
# %load_ext autoreload

# %% [markdown]
# Saving resuting figures and csv files in /home/t.afanasyeva/MAT_rnaseq/<yearmonthday>_output

# %%
p = Path().cwd().parent.parent
date = datetime.today().strftime("%Y%m%d")[2:]  # Get shortened year
RESULTS_PATH = p / f"{date}_output"
RESULTS_PATH.mkdir(parents=True, exist_ok=True)


def save_csv(table, table_name):
    """Save table in csv."""
    path = RESULTS_PATH / f"{table_name}.csv"
    table.to_csv(path)

# %% [markdown]
# ### 1. Prepare data

# %%
class DataProcessor:
    def __init__(
        self,
        raw_counts: pd.DataFrame,
        classes: list[str],
        n_cpus: int,
        batches: list[str] = None,
    ):
        self.raw_counts = raw_counts
        self.classes = classes
        self.batches = batches
        self.n_cpus = n_cpus

    def prepare_metadata(self) -> pd.DataFrame:
        """
        A method that checks if the list of batches was provided.
        If there are no batches, it checks the number of classes and subsets samples that belong to the classes,
        then it will prepare filtered counts and metadata. Otherwise, it will subset by class and batch and check
        if only one class was provided. Multiple batch comparisons are implemented here as only per one class!

        Returns tuple of counts and metadata

        """
        if not self.batches and len(self.classes) != 2:
            raise ValueError(
                "prepare_metadata() takes a list with two classes (str) as a condition."
            )
        if self.batches and len(self.classes) != 2:
            raise ValueError(
                "prepare_metadata() takes a list with one class (str) when batches provided."
            )

        samples_to_compare = list(
            self.raw_counts[
                self.raw_counts.index.get_level_values("label").isin(self.classes)
            ].index
        )

        number_of_unique_classes = len(
            (
                self.raw_counts.loc[samples_to_compare]
                .index.get_level_values("label")
                .unique()
            )
        )
        if number_of_unique_classes <= 1:
            raise ValueError(
                f"Provided counts for {number_of_unique_classes} class(es). Please provide counts for at least two classes."
            )

        metadata = pd.DataFrame(samples_to_compare, columns=["index", "condition"])
        metadata.set_index("index", inplace=True)

        if self.batches:
            metadata["batches"] = metadata.index.map(
                lambda sample: (
                    sample.split("_")[1]
                    if sample.split("_")[1] in self.batches
                    else None
                )
            )  # Retrieve batch number if the sample name as TA001_batch_class_replica
            metadata = metadata.dropna(subset=["batches"])
            if len(metadata["batches"].unique()) <= 1:
                raise ValueError(
                    f"Provided counts for {len(metadata['batches'].unique())} batch(es). Please provide counts for at least two batches."
                )

        return metadata

    def make_dds(self) -> AnnData:
        metadata = self.prepare_metadata()
        counts = self.raw_counts.loc[metadata.index]

        # Filtering genes that have a total sum of counts lower than 10
        counts = counts[counts.columns[counts.sum(axis=0) >= 10]]

        # Convert the multi-indexed DataFrame to a single-indexed one by resetting the index
        counts.reset_index(level="label", drop=True, inplace=True)

        dds = DeseqDataSet(
            counts=counts,
            metadata=metadata,
            design_factors=metadata.columns,
            refit_cooks=True,
            inference=DefaultInference(self.n_cpus),
        )
        dds.deseq2()
        return dds

    def make_statistics(
        self,
        padj_value: float = 0.05,
        log2foldchange_value: int = 2,
    ) -> tuple[AnnData, pd.DataFrame, pd.DataFrame]:

        dds = self.make_dds()

        if not self.batches:
            conditions_to_contrast = self.classes
            design_factor = "condition"
        else:
            conditions_to_contrast = self.batches
            design_factor = "group"

        stat_res = DeseqStats(
            dds,
            contrast=(design_factor, *conditions_to_contrast),
            inference=DefaultInference(self.n_cpus),
            quiet=True,
        )

        stat_res.summary()

        res = stat_res.results_df
        res = res[res.baseMean >= 10]

        # LImit the p value to minimal pvalue detected

        sigs = res[
            (res.padj < padj_value) & (abs(res.log2FoldChange) > log2foldchange_value)
        ]

        try:
            if sigs.empty:
                raise ValueError("No significant gene found.")
        except ValueError as e:
            print(e)

        return dds, res, sigs

# %% [markdown]
# ### 2. Make plots

# %%
class Plotter:
    geneid_symbol_mapper_human = None
    goeaobj = None
    total_go_terms = None
    is_initialized = False

    def __init__(
        self,
        dds: AnnData,
        res: pd.DataFrame,
        sigs: pd.DataFrame,
        analysis_name: str,
    ):
        self.dds = dds
        self.res = res
        self.sigs = sigs
        self.analysis_name = analysis_name

        if not Plotter.is_initialized:
            Plotter._initialise_go()
            Plotter.is_initialized = True

    def check_de_gene_list_not_empty(self):
        """Check if differentially expressed gene list is empty."""
        if self.sigs.empty:
            print("Warning: No significant genes found.")
            return False
        return True

    def make_figure(self, plot_type: str):
        if plot_type not in ["volcano", "histogram", "pca", "go"]:
            raise ValueError(
                "plot() takes 'volcano', 'histogram', 'pca' or 'go' as a condition."
            )
        fig_extension = "png"
        fname = RESULTS_PATH / f"{self.analysis_name}_{plot_type}.{fig_extension}"
        fontsize = 12

        if plot_type == "volcano":
            try:
                if self.sigs.empty:
                    raise ValueError("No significant gene found.")
            except ValueError as e:
                print(e)
                return

            print("Plotting volcano plot...")
            fig = self.plot_volcano()
            plt.title(
                f"{self.analysis_name} Differentially Expressed Genes",
                fontsize=fontsize,
                fontweight="bold",
            )

        if plot_type == "histogram":
            try:
                if self.sigs.empty:
                    raise ValueError("No significant gene found.")
            except ValueError as e:
                print(e)
                return

            print("Plotting histogram...")
            fig = self.plot_historgram()
            fig.ax_col_dendrogram.set_title(
                f"{self.analysis_name} Differentially Expressed Genes",
                fontsize=fontsize,
                fontweight="bold",
                pad=2,
            )

        if plot_type == "pca":
            fig = self.plot_pca()
            fig.axes[0].set_title(
                f"{self.analysis_name}", fontsize=fontsize, fontweight="bold"
            )

        if plot_type == "go":
            try:
                if self.sigs.empty:
                    raise ValueError("No significant gene found.")
            except ValueError as e:
                print(e)
                return

            print("Plotting GO terms...")
            fig = self.plot_go()
            plt.title(
                f"{self.analysis_name} Top 20 Significant GO Terms",
                fontsize=fontsize,
                fontweight="bold",
            )
            go_df = self.generate_go_table()
            save_csv(go_df, f"{self.analysis_name}_go_terms")

        fig.figure.savefig(
            fname,
            format=fig_extension,
            dpi=300,
            bbox_inches="tight",
        )

    def plot_volcano(self, log2foldchange=2):
        """Plot volcano."""
        # Add a small number to zeros to avoid inf in padj_log, taking log(0) error
        grapher = self.res.assign(
            padj_log=self.res["padj"].apply(
                lambda x: -np.log10(x) if x != 0 else -np.log10(x + 1e-300)
            ),
            color="no_expression_change",
        )

        grapher.loc[grapher["log2FoldChange"] > log2foldchange, "color"] = (
            "overexpressed"
        )
        grapher.loc[grapher["log2FoldChange"] < -log2foldchange, "color"] = (
            "underexpressed"
        )
        # Subset grapher to only overexpressed and underexpressed
        grapher_subset = grapher[
            grapher["color"].isin(["overexpressed", "underexpressed"])
        ]

        print(f"Number of DE genes: {len(grapher_subset)}")

        # Sort by padj_log (descending) and log2FoldChange (ascending)
        sorted_grapher_padj_log = grapher_subset.sort_values(
            by="padj_log", ascending=False
        )
        sorted_grapher_log2foldchange = grapher_subset.sort_values(
            by="log2FoldChange", ascending=True
        )
        print(f"Finished sorting DE genes.")

        # Select 20 genes for annotation (10 highest and 10 lowest)
        annotation_subset = pd.concat(
            [
                sorted_grapher_padj_log.head(20),
                sorted_grapher_log2foldchange.head(10),
                sorted_grapher_log2foldchange.tail(10),
            ]
        ).drop_duplicates()
        print(f"Selected top and bottom 20 DE genes for annotation.")

        g = plt.figure(figsize=(8, 10))
        rc = {
            "axes.spines.right": False,
            "axes.spines.top": False,
            "axes.titlepad": 20,
            "font.size": 10,
            "font.family": "sans-serif",
            "legend.frameon": "False",
            "legend.loc": "upper right",
            "lines.linestyle": "--",
            "lines.linewidth": 1,
            "lines.color": "k",
            "axes.facecolor": "white",
        }

        sns.set_theme(rc=rc)

        ax = sns.scatterplot(
            data=grapher,
            x="log2FoldChange",
            y="padj_log",
            hue="color",
            hue_order=["no_expression_change", "overexpressed", "underexpressed"],
            palette=["grey", "orange", "purple"],
            size="baseMean",
            sizes=(20, 50),
            alpha=0.7,
        )
        # Draw lines showing the threshold values
        ax.axhline(1.3, zorder=1)
        ax.axvline(2, zorder=1)
        ax.axvline(-2, zorder=1)
        # Add DE gene names (only for top 10% of sorted values)
        texts = []
        for i, row in annotation_subset.iterrows():
            texts.append(
                plt.text(
                    x=row.log2FoldChange,
                    y=row.padj_log,
                    s=row.name,
                    weight="bold",
                    size=8,
                )
            )

        adjust_text(texts, arrowprops=dict(arrowstyle="-", color="k"))
        plt.legend(bbox_to_anchor=(1.4, 1), prop={"size": 10, "weight": "bold"})
        plt.xticks(size=10, weight="bold")
        plt.yticks(size=10, weight="bold")
        plt.xlabel("$log_{2}$ fold change")
        plt.ylabel("-$log_{10}$ FDR")
        plt.ylim(-2, grapher["padj_log"].max() + 5)
        return g

    def plot_historgram(
        self, num_top_sig: Union[int, str] = 50
    ) -> tuple[figure.Figure, plt.Axes]:
        """Plot histogram of gene expression of genes with significant Benjamini-Hochberg adjusted p-values."""
        if num_top_sig != "all":
            sigs = self.sigs.sort_values("padj")[:num_top_sig]
        dds_sigs = self.dds[:, sigs.index]
        dds_sigs.layers["log1p"] = np.log1p(dds_sigs.layers["normed_counts"])
        sns.set_theme(rc={"ytick.labelsize": 8})
        grapher = pd.DataFrame(
            dds_sigs.layers["log1p"].T,
            index=dds_sigs.var_names,
            columns=dds_sigs.obs.condition,
        )

        lut = dict(zip(set(dds_sigs.obs.condition), "rgb"))
        col_colors = list(dds_sigs.obs.condition.map(lut))

        plt.figure(figsize=(8, 10), layout="tight")
        ax = sns.clustermap(
            figsize=(8, 10),
            data=grapher,
            cmap="RdYlBu_r",
            z_score=None,
            dendrogram_ratio=(0.1, 0.1),
            cbar_pos=(0.93, 0.2, 0.03, 0.45),
            cbar_kws=dict(
                location="left",
                orientation="vertical",
                pad=2,
            ),
            col_colors=col_colors,
        )

        handles = [Patch(facecolor=lut[name]) for name in lut]
        plt.legend(
            handles,
            lut,
            bbox_transform=plt.gcf().transFigure,
            bbox_to_anchor=(1, 1),
            loc="upper right",
            fontsize=10,
            fancybox=True,
            frameon=True,
            facecolor="white",
            edgecolor="black",
        )
        ax.ax_heatmap.set_xticklabels([])
        ax.ax_heatmap.set(xlabel=None)
        plt.subplots_adjust(hspace=0.01)
        return ax

    def plot_pca(self, w_text=False):
        dds = self.dds.copy()
        sc.tl.pca(dds, n_comps=2)
        pca = dds.obsm["X_pca"]
        sample_names = list(sc.get.obs_df(dds).index)
        rc = {
            "axes.facecolor": "white",
            "axes.edgecolor": "black",
        }
        sns.set_theme(rc=rc)
        plt.figure(figsize=(8, 10))
        ax = sc.pl.pca(
            dds, color="condition", size=300, show=False, title=" ", return_fig=True
        )  # color can also be group

        if w_text:
            texts = [
                plt.text(pca[i][0], pca[i][1], sample_names[i], ha="left", va="bottom")
                for i in range(len(pca))
            ]

        return ax

    @classmethod
    def _initialise_go(cls):
        """Get GO terms and initiate gotools classes."""
        print("Initializing GO terms...")

        path_to_supporting_files = Path().cwd() / "deseq2"

        """
        download_ncbi_associations() needed for gene2go returned critical connection error, 
        likely was not handled well by Sanquin's firewall. 
        I have downloaded the gene2go data from 
        ftp://ftp.ncbi.nlm.nih.gov/gene/DATA/gene2go.gz on 27-02-2025 and unzipped.
        """
        # gunzip(path_to_supporting_files / "gene2go.gz")
        genes = Gene2GoReader(
            path_to_supporting_files / "gene2go", taxids=[9606], namespaces={"BP"}
        )
        ns2assoc = genes.get_ns2assc()

        """Downloaded ontologies on 27-02-2025"""
        # obo_fname = download_go_basic_obo() # saves them to the same folder as this script
        obodag = GODag(path_to_supporting_files / "go-basic.obo")

        cls.goeaobj = GOEnrichmentStudyNS(
            GeneID2nt_hs.keys(),  # List of human protein-coding genes
            ns2assoc,  # Geneid/GO associations
            obodag,  # Ontologies
            propagate_counts=False,
            alpha=0.05,  # Default significance cut-off
            methods=["fdr_bh"],  # Default correction method for multiple testing
        )

        cls.geneid_symbol_mapper_human = {
            GeneID2nt_hs[key].Symbol: GeneID2nt_hs[key].GeneID for key in GeneID2nt_hs
        }

    def generate_go_table(self):
        """Retrieve GO terms per condition"""
        sigs_ids = [
            Plotter.geneid_symbol_mapper_human[gene]
            for gene in self.sigs.index
            if gene in Plotter.geneid_symbol_mapper_human
        ]
        print(
            f"Mapped {len(sigs_ids)/len(self.sigs.index)*100:.2f}% of",
            "GeneIDs of significantly differentially expressed genes symbols to gene IDs.",
        )

        goea_results = Plotter.goeaobj.run_study(sigs_ids, prt=None)
        goea_results_sig = [r for r in goea_results if r.p_fdr_bh < 0.05]

        inverted_mapping_dictionary = {
            v: k for k, v in Plotter.geneid_symbol_mapper_human.items()
        }  # Map study item IDs to gene symbols

        go_df = pd.DataFrame(
            list(
                map(
                    lambda x: [
                        x.GO,
                        x.goterm.name,
                        x.goterm.namespace,
                        x.p_uncorrected,
                        x.p_fdr_bh,
                        x.ratio_in_study[0],
                        x.ratio_in_study[1],
                        x.ratio_in_study[0] / x.ratio_in_study[1],
                        list(
                            map(lambda y: inverted_mapping_dictionary[y], x.study_items)
                        ),
                    ],
                    goea_results_sig,
                )
            ),
            columns=[
                "GO",
                "term",
                "class",
                "raw_pvalue",
                "fdr",
                "n_genes",
                "n_study",
                "ratio_in_study",
                "gene_symbols",
            ],
        )
        go_df["gene_symbols"] = go_df["gene_symbols"].apply(lambda x: ", ".join(x))
        go_df = go_df.sort_values("fdr", ascending=True)
        return go_df

    def plot_go(self):
        """Plot Go terms."""
        go_terms = self.generate_go_table()
        go_terms = go_terms[:20]
        go_terms = go_terms.sort_values("ratio_in_study", ascending=False)

        norm = mpl.colors.Normalize(vmin=go_terms.fdr.min(), vmax=go_terms.fdr.max())
        color_mapper = mpl.cm.ScalarMappable(norm=norm, cmap=mpl.cm.bwr_r)
        rc = {"axes.edgecolor": "black"}
        sns.set_theme(rc=rc)

        g = plt.figure(figsize=(10, 12))

        ax = sns.barplot(
            data=go_terms,
            x=go_terms["n_genes"] / go_terms["n_study"],
            y="term",
            palette=list(color_mapper.to_rgba(go_terms.fdr.values)),
        )

        ax.set_yticklabels(
            [textwrap.fill(term, 40) for term in go_terms["term"]],
            fontsize=2,  # Set font size 3 times larger (default is 12)
        )
        cbar = g.colorbar(
            color_mapper, ax=ax, orientation="vertical", pad=0.01, format="{x:.2f}"
        )
        cbar.ax.set_position([0.8, 0.5, 0.2, 0.3])
        cbar.ax.set_title("padj", loc="left", pad=4.0)

        return g

# %% [markdown]
# ### 6. Run analysis

# %%
file_path_multiindex = p / "resources/250624_training_multindex_108_7128.csv"
mi_counts = pd.read_csv(file_path_multiindex, index_col=[0, 1])
mi_counts.head()

# %%
mi_counts.rename(index={"IMDM": "nc"}, level="label", inplace=True)

# %%
# Create pairs with "negative control"
def make_pairs_with_negative_control(class_list):
    class_comparison_pair_list = []
    for my_class in class_list:
        class_comparison_pair_list.append([my_class, "nc"])
    return class_comparison_pair_list


class_list = ["Fla-PA", "LPS", "PGN", "R848", "Pam3", "PGN"]

# list_of_classes_to_include = [[my_class, "nc"] for my_class in class_list]
# for i, class_x in enumerate(class_list):
#     for class_y in class_list[i + 1 :]:
#         if class_x != class_y:
#             list_of_classes_to_include.append([class_x, class_y])

list_of_classes_to_include = make_pairs_with_negative_control(class_list)

# %%
# list_of_de_genes = []

combined_res = pd.DataFrame()

for class_pair in list_of_classes_to_include:
    analysis_name = f"{class_pair[0]}"
    print(f"Running analysis for {analysis_name}")

    dataprocessor = DataProcessor(raw_counts=mi_counts, classes=class_pair, n_cpus=42)
    dds, res, sigs = dataprocessor.make_statistics()
    save_csv(res, f"{analysis_name}_results")

# combined_res now contains all results with prefixed column names

set_of_de_genes = set(list_of_de_genes)

with open(RESULTS_PATH / "de_genes.txt", "w") as f:
    for gene in set_of_de_genes:
        f.write(f"{gene}\n")

# %% [markdown]
# Generatin DE gene lists for additional TLRS and HK bacteria samples

# %%
file_path_complete_data = p / "resources/250624_300.csv"
complete_data = pd.read_csv(file_path_complete_data, index_col=0)
complete_data["label"] = [label.split("_")[2] for label in complete_data.index]
complete_data.reset_index(inplace=True)
complete_data.set_index(["samples", "label"], inplace=True)
complete_data.rename(index={"IMDM": "nc"}, level="label", inplace=True)

# %%
class_list_additional_tlrs = ["LTA", "MPLA", "Pam2", "HKEB", "HKSA"]
# Create pairs with "negative control"
list_of_classes_to_include = make_pairs_with_negative_control(
    class_list_additional_tlrs
)
list_of_classes_to_include

# %%
list_of_de_genes = []
for class_pair in list_of_classes_to_include:
    analysis_name = f"{class_pair[0]}"
    print(f"Running analysis for {analysis_name}")

    dataprocessor = DataProcessor(
        raw_counts=complete_data, classes=class_pair, n_cpus=42
    )
    dds, res, sigs = dataprocessor.make_statistics()

    save_csv(res, f"{analysis_name}_results")
    # save_csv(sigs, f"{analysis_name}_statistically_significant_results")
    # list_of_de_genes.extend([gene for gene in sigs.index])

    # plotter = Plotter(dds, res, sigs, analysis_name)

    # plotter.make_figure("pca")
    # plotter.make_figure("histogram")
    # plotter.make_figure("volcano")
    # plotter.make_figure("go")

# %%
del merged_df

# %%
filelist = list(RESULTS_PATH.glob("*.csv"))
merged_df = pd.read_csv(filelist[0], index_col=0)
merged_df.rename(
    columns=lambda x: f'{x}_{filelist[0].stem.split("_")[0]}', inplace=True
)

for file in filelist[1:]:
    print(f"Processing file: {file.stem}")
    class_name = file.stem.split("_")[0]
    df = pd.read_csv(file, index_col=0)
    merged_df = pd.merge(
        merged_df,
        df,
        left_index=True,
        right_index=True,
        how="outer",
        suffixes=("", f"_{class_name}"),
        validate="one_to_one",
    )

print(merged_df.shape)

(RESULTS_PATH / "merged").mkdir(exist_ok=True)
merged_df.to_csv(RESULTS_PATH / "merged" / "merged_results.csv")
# Out:
# Processing file: LPS_results
# Processing file: PGN_results
# Processing file: R848_results
# Processing file: Pam3_results
# Processing file: LTA_results
# Processing file: MPLA_results
# Processing file: Pam2_results
# Processing file: HKEB_results
# Processing file: HKSA_results
# (12759, 60)

# %%
from pathlib import Path
import pandas as pd

path = Path("/home/t.afanasyeva/MAT_rnaseq/250625_output")
filelist = list(path.glob("*_go_terms.csv"))
merged_df = pd.read_csv(filelist[0], index_col=0)
merged_df.insert(loc=0, column="Ligand", value=filelist[0].stem.split("_")[0])

# %%
for file in filelist[1:]:
    print(f"Processing file: {file.stem}")
    class_name = file.stem.split("_")[0]
    df = pd.read_csv(file, index_col=0)
    df["Ligand"] = file.stem.split("_")[0]
    merged_df = pd.concat([merged_df, df], axis=0)

print(merged_df.shape)
# Out:
# Processing file: LPS_go_terms
# Processing file: PGN_go_terms
# Processing file: R848_go_terms
# Processing file: Pam3_go_terms
# (240, 10)

# %%
RESULTS_PATH = Path("/home/t.afanasyeva/MAT_rnaseq/250710_output")

# %%
merged_df.to_csv(RESULTS_PATH / "GO_DE_genes.csv")

# %%
merged_df
# Out:
#      Ligand          GO                                               term  \
# 0    Fla-PA  GO:0070098               chemokine-mediated signaling pathway
# 1    Fla-PA  GO:0031640               killing of cells of another organism
# 2    Fla-PA  GO:0006935                                         chemotaxis
# 3    Fla-PA  GO:0061844  antimicrobial humoral immune response mediated...
# 4    Fla-PA  GO:0010818                                  T cell chemotaxis
# 0       LPS  GO:0006954                              inflammatory response
# 1       LPS  GO:0006955                                    immune response
# 2       LPS  GO:0071222            cellular response to lipopolysaccharide
# 3       LPS  GO:0019221                cytokine-mediated signaling pathway
# 4       LPS  GO:0007267                                cell-cell signaling
# 5       LPS  GO:0030335              positive regulation of cell migration
# 6       LPS  GO:0061844  antimicrobial humoral immune response mediated...
# 7       LPS  GO:0010628             positive regulation of gene expression
# 8       LPS  GO:0060326                                    cell chemotaxis
# 9       LPS  GO:0010575  positive regulation of vascular endothelial gr...
# 10      LPS  GO:2000503  positive regulation of natural killer cell che...
# 11      LPS  GO:0008285  negative regulation of cell population prolife...
# 12      LPS  GO:0043615                           astrocyte cell migration
# 0       PGN  GO:0006954                              inflammatory response
# 1       PGN  GO:0007267                                cell-cell signaling
# 2       PGN  GO:0071222            cellular response to lipopolysaccharide
# 3       PGN  GO:0006955                                    immune response
# 4       PGN  GO:0061844  antimicrobial humoral immune response mediated...
# 5       PGN  GO:0006935                                         chemotaxis
# 6       PGN  GO:0030335              positive regulation of cell migration
# 7       PGN  GO:0030593                              neutrophil chemotaxis
# 8       PGN  GO:0031640               killing of cells of another organism
# 9       PGN  GO:0070098               chemokine-mediated signaling pathway
# 10      PGN  GO:0019221                cytokine-mediated signaling pathway
# 11      PGN  GO:0008285  negative regulation of cell population prolife...
# 12      PGN  GO:0070374       positive regulation of ERK1 and ERK2 cascade
# 13      PGN  GO:0045840    positive regulation of mitotic nuclear division
# 14      PGN  GO:0007165                                signal transduction
# 15      PGN  GO:0010628             positive regulation of gene expression
# 16      PGN  GO:0031622            positive regulation of fever generation
# 17      PGN  GO:0010744  positive regulation of macrophage derived foam...
# 18      PGN  GO:0010573      vascular endothelial growth factor production
# 19      PGN  GO:0048661  positive regulation of smooth muscle cell prol...
# 20      PGN  GO:0150078  positive regulation of neuroinflammatory response
# 21      PGN  GO:0010575  positive regulation of vascular endothelial gr...
# 22      PGN  GO:0150077           regulation of neuroinflammatory response
# 23      PGN  GO:0032308     positive regulation of prostaglandin secretion
# 24      PGN  GO:0030225                         macrophage differentiation
# 25      PGN  GO:2001240  negative regulation of extrinsic apoptotic sig...
# 26      PGN  GO:0051897  positive regulation of phosphatidylinositol 3-...
# 27      PGN  GO:0001821                                histamine secretion
# 28      PGN  GO:0045429  positive regulation of nitric oxide biosynthet...
# 29      PGN  GO:0010818                                  T cell chemotaxis
# 30      PGN  GO:0045910           negative regulation of DNA recombination
# 31      PGN  GO:0008284  positive regulation of cell population prolife...
# 32      PGN  GO:0048143                               astrocyte activation
# 34      PGN  GO:0001660                                   fever generation
# 35      PGN  GO:0042488  positive regulation of odontogenesis of dentin...
# 33      PGN  GO:0060559  positive regulation of calcidiol 1-monooxygena...
# 36      PGN  GO:0030224                           monocyte differentiation
# 37      PGN  GO:0030261                            chromosome condensation
# 38      PGN  GO:0032755    positive regulation of interleukin-6 production
# 39      PGN  GO:0048245                              eosinophil chemotaxis
# 40      PGN  GO:0060252    positive regulation of glial cell proliferation
# 41      PGN  GO:0001550                          ovarian cumulus expansion
# 42      PGN  GO:0010641  positive regulation of platelet-derived growth...
# 43      PGN  GO:0019722                         calcium-mediated signaling
# 44      PGN  GO:0050768                negative regulation of neurogenesis
# 45      PGN  GO:0032757    positive regulation of interleukin-8 production
# 46      PGN  GO:0010193                                  response to ozone
# 47      PGN  GO:2000503  positive regulation of natural killer cell che...
# 0      R848  GO:0051607                          defense response to virus
# 1      R848  GO:0009615                                  response to virus
# 2      R848  GO:0006955                                    immune response
# 3      R848  GO:0045071    negative regulation of viral genome replication
# 4      R848  GO:0045087                             innate immune response
# 5      R848  GO:0006954                              inflammatory response
# 6      R848  GO:0071222            cellular response to lipopolysaccharide
# 7      R848  GO:1901224  positive regulation of non-canonical NF-kappaB...
# 8      R848  GO:0140374                   antiviral innate immune response
# 9      R848  GO:0050729       positive regulation of inflammatory response
# 10     R848  GO:0010628             positive regulation of gene expression
# 11     R848  GO:0019221                cytokine-mediated signaling pathway
# 12     R848  GO:0032760  positive regulation of tumor necrosis factor p...
# 13     R848  GO:0007259  cell surface receptor signaling pathway via JA...
# 14     R848  GO:0032729  positive regulation of type II interferon prod...
# 15     R848  GO:0032728  positive regulation of interferon-beta production
# 16     R848  GO:0032755    positive regulation of interleukin-6 production
# 17     R848  GO:0035455                       response to interferon-alpha
# 18     R848  GO:0035456                        response to interferon-beta
# 19     R848  GO:0032722        positive regulation of chemokine production
# 20     R848  GO:0007267                                cell-cell signaling
# 21     R848  GO:0007166            cell surface receptor signaling pathway
# 22     R848  GO:0060337       type I interferon-mediated signaling pathway
# 23     R848  GO:0032757    positive regulation of interleukin-8 production
# 24     R848  GO:0045766                positive regulation of angiogenesis
# 25     R848  GO:0006915                                  apoptotic process
# 26     R848  GO:0070106          interleukin-27-mediated signaling pathway
# 27     R848  GO:0007165                                signal transduction
# 28     R848  GO:0042531  positive regulation of tyrosine phosphorylatio...
# 29     R848  GO:0006935                                         chemotaxis
# 30     R848  GO:0034341                     response to type II interferon
# 31     R848  GO:0042113                                  B cell activation
# 32     R848  GO:0030335              positive regulation of cell migration
# 33     R848  GO:0051092  positive regulation of NF-kappaB transcription...
# 34     R848  GO:0071346            cellular response to type II interferon
# 35     R848  GO:0043123  positive regulation of canonical NF-kappaB sig...
# 36     R848  GO:0043065           positive regulation of apoptotic process
# 37     R848  GO:0032735   positive regulation of interleukin-12 production
# 38     R848  GO:0008285  negative regulation of cell population prolife...
# 39     R848  GO:0032731  positive regulation of interleukin-1 beta prod...
# 40     R848  GO:0030890        positive regulation of B cell proliferation
# 41     R848  GO:0071639  positive regulation of monocyte chemotactic pr...
# 42     R848  GO:0001819         positive regulation of cytokine production
# 43     R848  GO:0098586                         cellular response to virus
# 44     R848  GO:0060339  negative regulation of type I interferon-media...
# 47     R848  GO:0034138             toll-like receptor 3 signaling pathway
# 45     R848  GO:0032725  positive regulation of granulocyte macrophage ...
# 46     R848  GO:0002430     complement receptor mediated signaling pathway
# 48     R848  GO:0090594                  inflammatory response to wounding
# 49     R848  GO:0032727  positive regulation of interferon-alpha produc...
# 50     R848  GO:0097191              extrinsic apoptotic signaling pathway
# 51     R848  GO:0060559  positive regulation of calcidiol 1-monooxygena...
# 52     R848  GO:1902216  positive regulation of interleukin-4-mediated ...
# 53     R848  GO:0150078  positive regulation of neuroinflammatory response
# 54     R848  GO:0032733   positive regulation of interleukin-10 production
# 55     R848  GO:0035458               cellular response to interferon-beta
# 56     R848  GO:0042832                      defense response to protozoan
# 57     R848  GO:0070098               chemokine-mediated signaling pathway
# 59     R848  GO:0030224                           monocyte differentiation
# 58     R848  GO:0071260           cellular response to mechanical stimulus
# 62     R848  GO:0045824      negative regulation of innate immune response
# 60     R848  GO:0042100                               B cell proliferation
# 61     R848  GO:0010575  positive regulation of vascular endothelial gr...
# 63     R848  GO:0043410                positive regulation of MAPK cascade
# 64     R848  GO:2000273  positive regulation of signaling receptor acti...
# 65     R848  GO:0042742                      defense response to bacterium
# 66     R848  GO:0039530                            MDA-5 signaling pathway
# 67     R848  GO:0009597                                 detection of virus
# 68     R848  GO:0001818         negative regulation of cytokine production
# 69     R848  GO:0002230  positive regulation of defense response to vir...
# 70     R848  GO:0045944  positive regulation of transcription by RNA po...
# 71     R848  GO:0032308     positive regulation of prostaglandin secretion
# 72     R848  GO:0030225                         macrophage differentiation
# 73     R848  GO:0006952                                   defense response
# 74     R848  GO:2001240  negative regulation of extrinsic apoptotic sig...
# 76     R848  GO:0010629             negative regulation of gene expression
# 75     R848  GO:0048661  positive regulation of smooth muscle cell prol...
# 77     R848  GO:0034154             toll-like receptor 7 signaling pathway
# 78     R848  GO:0031622            positive regulation of fever generation
# 79     R848  GO:0046597     host-mediated suppression of symbiont invasion
# 80     R848  GO:0070374       positive regulation of ERK1 and ERK2 cascade
# 81     R848  GO:0051091  positive regulation of DNA-binding transcripti...
# 82     R848  GO:0002281  macrophage activation involved in immune response
# 83     R848  GO:0043066           negative regulation of apoptotic process
# 84     R848  GO:0010573      vascular endothelial growth factor production
# 85     R848  GO:0032020                          ISG15-protein conjugation
# 86     R848  GO:0009750                               response to fructose
# 87     R848  GO:0045429  positive regulation of nitric oxide biosynthet...
# 88     R848  GO:0002224               toll-like receptor signaling pathway
# 89     R848  GO:0001774                         microglial cell activation
# 90     R848  GO:0042102        positive regulation of T cell proliferation
# 92     R848  GO:2000660  negative regulation of interleukin-1-mediated ...
# 91     R848  GO:0002067          glandular epithelial cell differentiation
# 93     R848  GO:0034142             toll-like receptor 4 signaling pathway
# 94     R848  GO:0048143                               astrocyte activation
# 95     R848  GO:0043011             myeloid dendritic cell differentiation
# 96     R848  GO:0071360               cellular response to exogenous dsRNA
# 97     R848  GO:0097421                                 liver regeneration
# 98     R848  GO:0070269                   pyroptotic inflammatory response
# 109    R848  GO:0060302           negative regulation of cytokine activity
# 108    R848  GO:0032834  positive regulation of CD4-positive, CD25-posi...
# 107    R848  GO:0034344       regulation of type III interferon production
# 106    R848  GO:0060557  positive regulation of vitamin D biosynthetic ...
# 105    R848  GO:0002876  positive regulation of chronic inflammatory re...
# 104    R848  GO:0001821                                histamine secretion
# 103    R848  GO:0002439  chronic inflammatory response to antigenic sti...
# 102    R848  GO:0097527                      necroptotic signaling pathway
# 101    R848  GO:0002237           response to molecule of bacterial origin
# 100    R848  GO:1903980  positive regulation of microglial cell activation
# 99     R848  GO:0007204  positive regulation of cytosolic calcium ion c...
# 110    R848  GO:0043122  regulation of canonical NF-kappaB signal trans...
# 111    R848  GO:0006968                          cellular defense response
# 112    R848  GO:0002753  cytoplasmic pattern recognition receptor signa...
# 113    R848  GO:0035633                 maintenance of blood-brain barrier
# 114    R848  GO:0033209   tumor necrosis factor-mediated signaling pathway
# 115    R848  GO:0001666                                response to hypoxia
# 118    R848  GO:0060252    positive regulation of glial cell proliferation
# 119    R848  GO:0010744  positive regulation of macrophage derived foam...
# 116    R848  GO:0045893  positive regulation of DNA-templated transcrip...
# 117    R848  GO:0048245                              eosinophil chemotaxis
# 120    R848  GO:0002218               activation of innate immune response
# 0      Pam3  GO:0006954                              inflammatory response
# 1      Pam3  GO:0006955                                    immune response
# 2      Pam3  GO:0030335              positive regulation of cell migration
# 3      Pam3  GO:0007267                                cell-cell signaling
# 4      Pam3  GO:0071222            cellular response to lipopolysaccharide
# 5      Pam3  GO:0019221                cytokine-mediated signaling pathway
# 6      Pam3  GO:0006935                                         chemotaxis
# 7      Pam3  GO:0061844  antimicrobial humoral immune response mediated...
# 8      Pam3  GO:0010628             positive regulation of gene expression
# 9      Pam3  GO:0051897  positive regulation of phosphatidylinositol 3-...
# 10     Pam3  GO:0007166            cell surface receptor signaling pathway
# 11     Pam3  GO:0008285  negative regulation of cell population prolife...
# 13     Pam3  GO:0031640               killing of cells of another organism
# 12     Pam3  GO:0007165                                signal transduction
# 14     Pam3  GO:0070098               chemokine-mediated signaling pathway
# 15     Pam3  GO:0070374       positive regulation of ERK1 and ERK2 cascade
# 16     Pam3  GO:0031622            positive regulation of fever generation
# 17     Pam3  GO:0045429  positive regulation of nitric oxide biosynthet...
# 18     Pam3  GO:0010573      vascular endothelial growth factor production
# 19     Pam3  GO:0010744  positive regulation of macrophage derived foam...
# 20     Pam3  GO:0060326                                    cell chemotaxis
# 21     Pam3  GO:0150078  positive regulation of neuroinflammatory response
# 22     Pam3  GO:0002548                                monocyte chemotaxis
# 23     Pam3  GO:0030593                              neutrophil chemotaxis
# 24     Pam3  GO:0032731  positive regulation of interleukin-1 beta prod...
# 25     Pam3  GO:0045840    positive regulation of mitotic nuclear division
# 26     Pam3  GO:0010575  positive regulation of vascular endothelial gr...
# 27     Pam3  GO:0032308     positive regulation of prostaglandin secretion
# 28     Pam3  GO:0032757    positive regulation of interleukin-8 production
# 29     Pam3  GO:0001821                                histamine secretion
# 30     Pam3  GO:0019722                         calcium-mediated signaling
# 31     Pam3  GO:0035633                 maintenance of blood-brain barrier
# 32     Pam3  GO:2001240  negative regulation of extrinsic apoptotic sig...
# 33     Pam3  GO:0006885                                   regulation of pH
# 34     Pam3  GO:0010629             negative regulation of gene expression
# 35     Pam3  GO:0008284  positive regulation of cell population prolife...
# 36     Pam3  GO:0048566              embryonic digestive tract development
# 37     Pam3  GO:0043410                positive regulation of MAPK cascade
# 39     Pam3  GO:0001660                                   fever generation
# 38     Pam3  GO:0060559  positive regulation of calcidiol 1-monooxygena...
# 40     Pam3  GO:0048143                               astrocyte activation
# 41     Pam3  GO:0045766                positive regulation of angiogenesis
# 42     Pam3  GO:0030224                           monocyte differentiation
# 43     Pam3  GO:0032715    negative regulation of interleukin-6 production
# 44     Pam3  GO:0048245                              eosinophil chemotaxis
# 45     Pam3  GO:0060252    positive regulation of glial cell proliferation
# 46     Pam3  GO:0001550                          ovarian cumulus expansion
# 47     Pam3  GO:0010641  positive regulation of platelet-derived growth...
# 48     Pam3  GO:0090024       negative regulation of neutrophil chemotaxis
# 49     Pam3  GO:0048661  positive regulation of smooth muscle cell prol...
# 51     Pam3  GO:0030198                  extracellular matrix organization
# 50     Pam3  GO:0050729       positive regulation of inflammatory response
# 52     Pam3  GO:0007259  cell surface receptor signaling pathway via JA...
#
#                   class    raw_pvalue           fdr  n_genes  n_study  \
# 0    biological_process  1.171771e-06  1.415500e-02        3        8
# 1    biological_process  4.585781e-06  2.769812e-02        3        8
# 2    biological_process  9.523999e-06  3.334517e-02        3        8
# 3    biological_process  1.163620e-05  3.334517e-02        3        8
# 4    biological_process  1.380181e-05  3.334517e-02        2        8
# 0    biological_process  4.858550e-13  5.869129e-09       12       32
# 1    biological_process  2.628192e-12  1.587428e-08       11       32
# 2    biological_process  1.852250e-10  7.458393e-07        8       32
# 3    biological_process  1.365441e-09  4.123630e-06        7       32
# 4    biological_process  1.836917e-09  4.437992e-06        8       32
# 5    biological_process  1.235836e-07  2.488151e-04        7       32
# 6    biological_process  1.283721e-06  2.215335e-03        5       32
# 7    biological_process  3.454525e-06  5.216333e-03        7       32
# 8    biological_process  8.454680e-06  1.134806e-02        4       32
# 9    biological_process  1.482665e-05  1.791059e-02        3       32
# 10   biological_process  2.327563e-05  2.556087e-02        2       32
# 11   biological_process  2.598281e-05  2.615603e-02        6       32
# 12   biological_process  4.878404e-05  4.533163e-02        2       32
# 0    biological_process  1.264953e-22  1.528064e-18       25       86
# 1    biological_process  3.092514e-18  1.867878e-14       18       86
# 2    biological_process  5.062481e-16  2.038493e-12       15       86
# 3    biological_process  7.213104e-14  2.178357e-10       17       86
# 4    biological_process  1.368531e-13  3.306370e-10       12       86
# 5    biological_process  5.306215e-11  1.052362e-07       10       86
# 6    biological_process  6.098123e-11  1.052362e-07       13       86
# 7    biological_process  2.591062e-09  3.912503e-06        7       86
# 8    biological_process  4.219665e-09  5.243088e-06        8       86
# 9    biological_process  4.340305e-09  5.243088e-06        7       86
# 10   biological_process  5.422952e-09  5.955387e-06        9       86
# 11   biological_process  7.488317e-08  7.538239e-05       12       86
# 12   biological_process  1.083516e-07  1.006836e-04        9       86
# 13   biological_process  1.474419e-07  1.272213e-04        5       86
# 14   biological_process  2.136541e-07  1.626308e-04       19       86
# 15   biological_process  2.154050e-07  1.626308e-04       12       86
# 16   biological_process  6.967595e-07  4.951091e-04        3       86
# 17   biological_process  1.299648e-06  8.722081e-04        4       86
# 18   biological_process  1.389312e-06  8.833098e-04        3       86
# 19   biological_process  2.753706e-06  1.663238e-03        5       86
# 20   biological_process  3.866625e-06  2.224230e-03        3       86
# 21   biological_process  8.150056e-06  4.325532e-03        4       86
# 22   biological_process  8.235699e-06  4.325532e-03        3       86
# 23   biological_process  1.128993e-05  5.682596e-03        3       86
# 24   biological_process  1.189827e-05  5.749243e-03        4       86
# 25   biological_process  1.501695e-05  6.977105e-03        4       86
# 26   biological_process  1.627090e-05  7.279719e-03        7       86
# 27   biological_process  1.720172e-05  7.421312e-03        2       86
# 28   biological_process  2.799603e-05  1.166179e-02        4       86
# 29   biological_process  3.075901e-05  1.192466e-02        3       86
# 30   biological_process  3.075901e-05  1.192466e-02        3       86
# 31   biological_process  3.158850e-05  1.192466e-02       10       86
# 32   biological_process  4.569284e-05  1.672635e-02        3       86
# 34   biological_process  5.146495e-05  1.726935e-02        2       86
# 35   biological_process  5.146495e-05  1.726935e-02        2       86
# 33   biological_process  5.146495e-05  1.726935e-02        2       86
# 36   biological_process  5.466619e-05  1.737809e-02        3       86
# 37   biological_process  5.466619e-05  1.737809e-02        3       86
# 38   biological_process  5.905401e-05  1.829160e-02        5       86
# 39   biological_process  7.591245e-05  2.236640e-02        3       86
# 40   biological_process  7.591245e-05  2.236640e-02        3       86
# 41   biological_process  1.026504e-04  2.883759e-02        2       86
# 42   biological_process  1.026504e-04  2.883759e-02        2       86
# 43   biological_process  1.107204e-04  3.039778e-02        5       86
# 44   biological_process  1.331620e-04  3.574660e-02        3       86
# 45   biological_process  1.574240e-04  4.134090e-02        4       86
# 46   biological_process  1.706194e-04  4.293922e-02        2       86
# 47   biological_process  1.706194e-04  4.293922e-02        2       86
# 0    biological_process  2.095143e-38  2.530932e-34       50      391
# 1    biological_process  5.106211e-28  3.084152e-24       31      391
# 2    biological_process  2.007981e-25  8.085470e-22       46      391
# 3    biological_process  1.441764e-23  4.354128e-20       20      391
# 4    biological_process  2.142829e-21  5.177074e-18       49      391
# 5    biological_process  2.472018e-18  4.976996e-15       41      391
# 6    biological_process  3.082902e-16  5.320208e-13       26      391
# 7    biological_process  5.745345e-14  7.711529e-11       16      391
# 8    biological_process  5.745345e-14  7.711529e-11       16      391
# 9    biological_process  6.064346e-13  7.325729e-10       18      391
# 10   biological_process  1.046036e-11  1.148737e-08       33      391
# 11   biological_process  1.237520e-11  1.245771e-08       19      391
# 12   biological_process  1.347096e-11  1.251763e-08       17      391
# 13   biological_process  4.823676e-10  4.162143e-07       12      391
# 14   biological_process  2.438061e-09  1.963452e-06       13      391
# 15   biological_process  3.566567e-09  2.692758e-06       10      391
# 16   biological_process  5.449962e-09  3.872679e-06       14      391
# 17   biological_process  8.825256e-09  5.611005e-06        6      391
# 18   biological_process  8.825256e-09  5.611005e-06        6      391
# 19   biological_process  9.485784e-09  5.729413e-06       10      391
# 20   biological_process  1.912449e-08  1.100113e-05       20      391
# 21   biological_process  2.171642e-08  1.192429e-05       21      391
# 22   biological_process  2.283904e-08  1.199546e-05       10      391
# 23   biological_process  3.550524e-08  1.787097e-05       11      391
# 24   biological_process  7.905736e-08  3.820051e-05       15      391
# 25   biological_process  8.584861e-08  3.988658e-05       31      391
# 26   biological_process  1.278584e-07  5.720480e-05        5      391
# 27   biological_process  1.494520e-07  6.447786e-05       49      391
# 28   biological_process  2.192803e-07  9.134158e-05        7      391
# 29   biological_process  3.175882e-07  1.278822e-04       13      391
# 30   biological_process  4.033346e-07  1.571704e-04        7      391
# 31   biological_process  4.635297e-07  1.749825e-04        8      391
# 32   biological_process  6.516031e-07  2.385262e-04       19      391
# 33   biological_process  8.106836e-07  2.880311e-04       12      391
# 34   biological_process  1.011211e-06  3.490123e-04       10      391
# 35   biological_process  1.047671e-06  3.515519e-04       17      391
# 36   biological_process  1.128195e-06  3.683405e-04       20      391
# 37   biological_process  1.520979e-06  4.835112e-04        8      391
# 38   biological_process  1.698377e-06  5.260614e-04       23      391
# 39   biological_process  1.823039e-06  5.505578e-04        9      391
# 40   biological_process  2.567917e-06  7.565959e-04        8      391
# 41   biological_process  2.716647e-06  7.798716e-04        5      391
# 42   biological_process  2.776033e-06  7.798716e-04        9      391
# 43   biological_process  3.044521e-06  8.358594e-04       10      391
# 44   biological_process  3.441472e-06  9.238442e-04        6      391
# 47   biological_process  4.160160e-06  1.046974e-03        5      391
# 45   biological_process  4.160160e-06  1.046974e-03        5      391
# 46   biological_process  4.160160e-06  1.046974e-03        5      391
# 48   biological_process  4.263599e-06  1.051108e-03        4      391
# 49   biological_process  5.846882e-06  1.412607e-03        6      391
# 50   biological_process  6.554317e-06  1.543459e-03        8      391
# 51   biological_process  6.771800e-06  1.543459e-03        3      391
# 52   biological_process  6.771800e-06  1.543459e-03        3      391
# 53   biological_process  8.399341e-06  1.878964e-03        4      391
# 54   biological_process  1.078858e-05  2.369564e-03        7      391
# 55   biological_process  1.185350e-05  2.512110e-03        6      391
# 56   biological_process  1.185350e-05  2.512110e-03        6      391
# 57   biological_process  1.305113e-05  2.718234e-03        8      391
# 59   biological_process  1.672323e-05  3.366943e-03        5      391
# 58   biological_process  1.665570e-05  3.366943e-03        9      391
# 62   biological_process  2.207842e-05  4.233449e-03        6      391
# 60   biological_process  2.207842e-05  4.233449e-03        6      391
# 61   biological_process  2.207842e-05  4.233449e-03        6      391
# 63   biological_process  2.265745e-05  4.276594e-03       14      391
# 64   biological_process  2.444871e-05  4.543699e-03        4      391
# 65   biological_process  2.632911e-05  4.681735e-03       12      391
# 66   biological_process  2.670478e-05  4.681735e-03        3      391
# 67   biological_process  2.670478e-05  4.681735e-03        3      391
# 68   biological_process  2.674170e-05  4.681735e-03        6      391
# 69   biological_process  3.216517e-05  5.550790e-03        6      391
# 70   biological_process  3.750823e-05  6.349447e-03       43      391
# 71   biological_process  3.784438e-05  6.349447e-03        4      391
# 72   biological_process  3.843756e-05  6.360626e-03        6      391
# 73   biological_process  5.273947e-05  8.609362e-03        8      391
# 74   biological_process  5.391530e-05  8.683958e-03        6      391
# 76   biological_process  6.126748e-05  9.611833e-03       15      391
# 75   biological_process  6.084005e-05  9.611833e-03        7      391
# 77   biological_process  6.582028e-05  1.006467e-02        3      391
# 78   biological_process  6.582028e-05  1.006467e-02        3      391
# 79   biological_process  7.553557e-05  1.140587e-02        5      391
# 80   biological_process  8.075631e-05  1.204366e-02       13      391
# 81   biological_process  1.047644e-04  1.543358e-02        8      391
# 82   biological_process  1.097231e-04  1.596934e-02        4      391
# 83   biological_process  1.230643e-04  1.769782e-02       22      391
# 84   biological_process  1.297855e-04  1.802079e-02        3      391
# 85   biological_process  1.297855e-04  1.802079e-02        3      391
# 86   biological_process  1.297855e-04  1.802079e-02        3      391
# 87   biological_process  1.319323e-04  1.811070e-02        6      391
# 88   biological_process  1.369109e-04  1.837648e-02        5      391
# 89   biological_process  1.369109e-04  1.837648e-02        5      391
# 90   biological_process  1.677172e-04  2.226399e-02        7      391
# 92   biological_process  2.239269e-04  2.908642e-02        3      391
# 91   biological_process  2.239269e-04  2.908642e-02        3      391
# 93   biological_process  2.306455e-04  2.964039e-02        5      391
# 94   biological_process  2.493758e-04  3.105629e-02        4      391
# 95   biological_process  2.493758e-04  3.105629e-02        4      391
# 96   biological_process  2.493758e-04  3.105629e-02        4      391
# 97   biological_process  2.707545e-04  3.337464e-02        5      391
# 98   biological_process  3.159421e-04  3.855131e-02        5      391
# 109  biological_process  3.588358e-04  3.940669e-02        2      391
# 108  biological_process  3.588358e-04  3.940669e-02        2      391
# 107  biological_process  3.588358e-04  3.940669e-02        2      391
# 106  biological_process  3.588358e-04  3.940669e-02        2      391
# 105  biological_process  3.588358e-04  3.940669e-02        2      391
# 104  biological_process  3.588358e-04  3.940669e-02        2      391
# 103  biological_process  3.588358e-04  3.940669e-02        2      391
# 102  biological_process  3.532434e-04  3.940669e-02        3      391
# 101  biological_process  3.532434e-04  3.940669e-02        3      391
# 100  biological_process  3.532434e-04  3.940669e-02        3      391
# 99   biological_process  3.461102e-04  3.940669e-02       10      391
# 110  biological_process  3.666165e-04  3.989844e-02        5      391
# 111  biological_process  3.924271e-04  4.213203e-02        6      391
# 112  biological_process  3.941158e-04  4.213203e-02        4      391
# 113  biological_process  4.231991e-04  4.484425e-02        5      391
# 114  biological_process  4.366128e-04  4.552515e-02        6      391
# 115  biological_process  4.371620e-04  4.552515e-02       11      391
# 118  biological_process  4.853125e-04  4.853198e-02        4      391
# 119  biological_process  4.853125e-04  4.853198e-02        4      391
# 116  biological_process  4.803805e-04  4.853198e-02       27      391
# 117  biological_process  4.853125e-04  4.853198e-02        4      391
# 120  biological_process  4.861233e-04  4.853198e-02        5      391
# 0    biological_process  3.620349e-21  4.373381e-17       26      108
# 1    biological_process  1.122228e-16  6.778258e-13       21      108
# 2    biological_process  4.953590e-13  1.994645e-09       16      108
# 3    biological_process  1.216825e-12  3.674812e-09       15      108
# 4    biological_process  6.701447e-12  1.360215e-08       13      108
# 5    biological_process  6.756034e-12  1.360215e-08       12      108
# 6    biological_process  2.410999e-11  4.160696e-08       11      108
# 7    biological_process  1.011315e-09  1.527085e-06       10      108
# 8    biological_process  5.455001e-08  7.321823e-05       14      108
# 9    biological_process  7.163163e-08  8.653100e-05       10      108
# 10   biological_process  1.042527e-07  1.144884e-04       11      108
# 11   biological_process  1.284571e-07  1.293135e-04       13      108
# 13   biological_process  5.017547e-07  4.329426e-04        7      108
# 12   biological_process  4.929739e-07  4.329426e-04       21      108
# 14   biological_process  5.830279e-07  4.695318e-04        6      108
# 15   biological_process  7.729595e-07  5.835844e-04        9      108
# 16   biological_process  1.387721e-06  9.860980e-04        3      108
# 17   biological_process  2.620747e-06  1.757858e-03        5      108
# 18   biological_process  2.764842e-06  1.757858e-03        3      108
# 19   biological_process  3.235269e-06  1.954102e-03        4      108
# 20   biological_process  5.244306e-06  3.016725e-03        6      108
# 21   biological_process  7.682561e-06  4.218425e-03        3      108
# 22   biological_process  8.278362e-06  4.347940e-03        4      108
# 23   biological_process  9.268768e-06  4.665280e-03        5      108
# 24   biological_process  1.561255e-05  7.543983e-03        5      108
# 25   biological_process  1.757627e-05  8.166208e-03        4      108
# 26   biological_process  2.009898e-05  8.992434e-03        4      108
# 27   biological_process  2.237799e-05  9.633494e-03        3      108
# 28   biological_process  2.312676e-05  9.633494e-03        5      108
# 29   biological_process  2.719330e-05  1.094984e-02        2      108
# 30   biological_process  2.883255e-05  1.104857e-02        6      108
# 31   biological_process  2.926773e-05  1.104857e-02        4      108
# 32   biological_process  3.687641e-05  1.349900e-02        4      108
# 33   biological_process  3.849325e-05  1.367642e-02        3      108
# 34   biological_process  4.000725e-05  1.380822e-02        8      108
# 35   biological_process  4.482128e-05  1.504003e-02       11      108
# 36   biological_process  7.451286e-05  2.408824e-02        3      108
# 37   biological_process  7.577427e-05  2.408824e-02        7      108
# 39   biological_process  8.130022e-05  2.455267e-02        2      108
# 38   biological_process  8.130022e-05  2.455267e-02        2      108
# 40   biological_process  9.013519e-05  2.655691e-02        3      108
# 41   biological_process  9.934536e-05  2.857362e-02        6      108
# 42   biological_process  1.077503e-04  3.027030e-02        3      108
# 43   biological_process  1.160698e-04  3.186644e-02        4      108
# 44   biological_process  1.493893e-04  3.923092e-02        3      108
# 45   biological_process  1.493893e-04  3.923092e-02        3      108
# 46   biological_process  1.620432e-04  3.994862e-02        2      108
# 47   biological_process  1.620432e-04  3.994862e-02        2      108
# 48   biological_process  1.620432e-04  3.994862e-02        2      108
# 49   biological_process  1.711983e-04  4.136152e-02        4      108
# 51   biological_process  1.916888e-04  4.453079e-02        6      108
# 50   biological_process  1.910227e-04  4.453079e-02        5      108
# 52   biological_process  2.121610e-04  4.835671e-02        4      108
#
#      ratio_in_study                                       gene_symbols
# 0          0.375000                               CXCL10, CXCL11, CCL8
# 1          0.375000                               CXCL10, CXCL11, CCL8
# 2          0.375000                               CXCL10, CXCL11, CCL8
# 3          0.375000                               CXCL10, CXCL11, CCL8
# 4          0.250000                                     CXCL10, CXCL11
# 0          0.375000  IL1A, ADORA2A, CXCL2, CCL3, IL36G, CCL3L3, CCL...
# 1          0.343750  CSF3, IL1A, PRG4, CXCL2, IL36G, TNFSF15, CCL4,...
# 2          0.250000  CSF3, IL1A, IL36G, PTGS2, IL6, TNIP3, IL36RN, ...
# 3          0.218750           CSF3, IL1A, GREM2, INHBA, F3, IL36G, IL6
# 4          0.250000  ADORA2A, INHBA, CCL3, IL36G, CCL4, GJB2, TNFAI...
# 5          0.218750       MMP14, F3, CCL3, CCL3L3, CCL4, TNFAIP6, CSF2
# 6          0.156250                   CXCL2, CCL3, CCL3L3, CCL4, CCL20
# 7          0.218750            IL1A, INHBA, F3, CCL3, ITGB8, IL6, CSF2
# 8          0.125000                         CXCL2, CCL20, CCL3, CCL3L3
# 9          0.093750                                   IL1A, IL6, PTGS2
# 10         0.062500                                         CCL3, CCL4
# 11         0.187500           IL1A, ADORA2A, INHBA, CCL3L3, PTGS2, IL6
# 12         0.062500                                        MMP14, CCL3
# 0          0.290698  ADORA2A, SCUBE1, CSF1, CSF1R, IL36RN, CXCL10, ...
# 1          0.209302  IL1B, CXCL11, CXCL5, ADORA2A, INHBA, CXCL10, C...
# 2          0.174419  CSF3, IL1A, IL1B, CXCL5, CXCL8, CXCL10, IL36G,...
# 3          0.197674  CSF3, SLAMF8, FCGR1A, ADAMDEC1, IL1A, CXCL11, ...
# 4          0.139535  CXCL11, CXCL5, CXCL2, CXCL3, CXCL10, CCL3, CCL...
# 5          0.116279  CXCL11, CXCL5, CXCL2, CXCL10, CCL3, CCL8, FPR3...
# 6          0.151163  IL1B, F3, CCL3, SPRY2, CCL3L3, CCL4, EDN1, CCL...
# 7          0.081395     IL1B, CXCL5, CXCL3, CXCL10, CCL3, CXCL8, CXCL9
# 8          0.093023  CXCL11, CXCL2, CXCL3, CXCL10, CCL8, CXCL8, CXC...
# 9          0.081395    CXCL11, CXCL10, CCL3, CCL3L3, CCL4, CCL8, CXCL9
# 10         0.104651  CSF3, IL1A, IL1B, INHBA, F3, IL36G, IL6, EREG,...
# 11         0.139535  IL1A, IL1B, ADORA2A, INHBA, SPRY2, CCL3L3, PTG...
# 12         0.104651  IL1A, IL1B, ADORA2A, INHBA, CCL3, SPRY2, TNF, ...
# 13         0.058140                        IL1A, IL1B, EDN1, TNF, EREG
# 14         0.220930  SCUBE1, CSF1R, IL36RN, FCGR1A, CXCL10, FPR3, C...
# 15         0.139535  IL1A, IL1B, INHBA, F3, CCL3, SPRY2, ITGB8, IL6...
# 16         0.034884                                   IL1B, TNF, PTGS2
# 17         0.046512                              IL1B, CSF1, TNF, CSF2
# 18         0.034884                                     IL1B, TNF, IL6
# 19         0.058140                        PTGS2, IL6, EDN1, TNF, EREG
# 20         0.034884                                     IL1B, TNF, IL6
# 21         0.046512                             IL1A, IL1B, IL6, PTGS2
# 22         0.034884                                   IL6, MMP9, PTGS2
# 23         0.034884                                   IL1A, IL1B, EDN1
# 24         0.046512                            CSF1, CSF1R, CSF2, MMP9
# 25         0.046512                              IL1A, IL1B, TNF, CSF2
# 26         0.081395         CSF3, IL1B, CCL3, SPRY2, TNF, CSF1R, MERTK
# 27         0.023256                                         EDN1, CSF2
# 28         0.046512                             IL1B, EDN1, TNF, PTGS2
# 29         0.034884                               CXCL10, CCL3, CXCL11
# 30         0.034884                                  H1-10, H1-0, H1-2
# 31         0.116279  CSF3, IL1B, CXCL5, CXCL10, IL6, EDN1, EREG, CS...
# 32         0.034884                                 IL1B, TNF, ADORA2A
# 34         0.023256                                         IL1A, IL1B
# 35         0.023256                                         CSF1, NGFR
# 33         0.023256                                          IL1B, TNF
# 36         0.034884                                  CSF1, CSF1R, CSF2
# 37         0.034884                                  H1-10, H1-0, H1-2
# 38         0.058140                         IL1A, IL1B, IL6, TNF, EREG
# 39         0.034884                                   CCL8, CCL3, CCL4
# 40         0.034884                                     IL1B, TNF, IL6
# 41         0.023256                                      TNFAIP6, EREG
# 42         0.023256                                           F3, IL1B
# 43         0.058140                      CCL3, EDN1, TNF, CXCL8, CCL20
# 44         0.034884                                     IL1B, TNF, IL6
# 45         0.046512                                 F3, IL1B, TNF, IL6
# 46         0.023256                                         IL1A, EDN1
# 47         0.023256                                         CCL3, CCL4
# 0          0.127877  IFNG, ZBP1, IFIH1, ACOD1, IL12B, HERC5, RSAD2,...
# 1          0.079284  IFNG, IFIH1, NMI, RSAD2, DHX58, RIGI, ISG15, I...
# 2          0.117647  SLAMF8, IL10, CXCR5, LIF, IL18, FCRL3, ICOS, C...
# 3          0.051151  IFIH1, RSAD2, ISG15, SHFL, IFITM3, BST2, OASL,...
# 4          0.125320  IFIH1, TRAF4, HERC5, NMI, RSAD2, SAMD9, NEURL3...
# 5          0.104859  TBXA2R, HDAC9, ACOD1, IL18, CSF1R, IL36RN, CD1...
# 6          0.066496  EPHB2, IL10, TBXA2R, ACOD1, IL12B, IL18, CSF2,...
# 7          0.040921  IL1B, IFI35, IL12B, EIF2AK2, LGALS9, NLRP12, E...
# 8          0.040921  RIGI, ZBP1, IFIH1, IFIT2, OAS1, OAS2, OAS3, US...
# 9          0.046036  TLR3, CCL24, IFNG, IL1B, ZBP1, IFI35, IL12B, C...
# 10         0.084399  EPHB2, MYC, IFNG, LIF, ALDH1A2, NOG, GDF7, RAR...
# 11         0.048593  CISH, SOCS2, GREM2, IL12RB2, IL31RA, IL18, CSF...
# 12         0.043478  EPHB2, FCGR1A, CD14, TLR3, RIGI, IFNG, IL1A, I...
# 13         0.030691  IFNG, SOCS2, IL12B, SOCS1, IL6, IL15RA, IL31RA...
# 14         0.033248  CD14, IL1B, ISG15, EBI3, IL12B, IL12RB2, LGALS...
# 15         0.025575  TLR3, RIGI, ISG15, IFIH1, OAS1, OAS2, OAS3, IR...
# 16         0.035806  IL1A, IL1B, RIGI, IFNG, SCIMP, IFIH1, LGALS9, ...
# 17         0.015345          LAMP3, IFITM1, IFITM3, EIF2AK2, BST2, MX2
# 18         0.015345           IFITM1, SHFL, IFITM3, BST2, PLSCR1, XAF1
# 19         0.025575  IFNG, HMOX1, EIF2AK2, IL6, TNF, TLR7, IL18, TL...
# 20         0.051151  FZD1, GJB2, IL18, TNFSF10, INHBA, CCL3, CCL4, ...
# 21         0.053708  IFNG, IL12RB2, TRAF4, FCRL3, FCGR1A, CD14, P2R...
# 22         0.025575  CR2, IFIH1, IFITM1, IFITM3, OAS1, OAS2, OAS3, ...
# 23         0.028133  TLR3, CD14, RIGI, IL1B, F3, IL6, TLR7, TNF, TL...
# 24         0.038363  IL1A, CCL24, IL1B, TBXA2R, HMOX1, ENG, F3, CXC...
# 25         0.079284  IFNG, ZBP1, BCL2L14, TRAF1, TRAF4, TNFRSF9, RA...
# 26         0.012788                        OAS1, OAS2, OAS3, MX1, OASL
# 27         0.125320  ICOSLG, NLRP12, MACC1, CSF1R, IL36RN, KREMEN1,...
# 28         0.017903  PARP14, IFNG, TNFRSF18, PARP9, IL31RA, IL18, C...
# 29         0.033248  CCL24, C5AR2, CXCL11, PLGRKT, CXCL2, CXCL8, CC...
# 30         0.017903     IFITM1, SHFL, IFITM3, BST2, TRIM21, NUB1, CD40
# 31         0.020460  EPHB2, CXCR5, CR2, HDAC9, BST2, ICOSLG, CHRNB2...
# 32         0.048593  EPHB2, SYNPO2, FLT1, CSF1R, CSF2, SEMA7A, PECA...
# 33         0.030691  IL1B, TRIM14, TRIM22, EIF2AK2, RAB7B, TRAF1, T...
# 34         0.025575  GBP4, ACOD1, IL12B, CCL3, PIM1, RAB7B, EDN1, T...
# 35         0.043478  TLR3, IL1A, IL1B, HMOX1, TNFSF10, TRIM22, IFIT...
# 36         0.051151  ZBP1, TGM2, ALDH1A2, RARG, TNFSF10, TLR3, PIP5...
# 37         0.020460  IFNG, SCIMP, IL12B, LGALS9, UNC93B1, TLR3, TLR...
# 38         0.058824  IL10, LIF, TNFRSF9, ALDH1A2, NMI, CSF1R, RARG,...
# 39         0.023018  IFNG, IFI16, CCL3, NLRP12, IL6, NLRC4, TNF, NL...
# 40         0.020460  EPHB2, TNFRSF13C, CHRNB2, CD38, FCRL3, TLR9, T...
# 41         0.012788                   IL1B, OAS1, OAS3, LGALS9, MCOLN2
# 42         0.023018  IL1A, CD14, IFNG, IL10, IFI16, BATF, EIF2AK2, ...
# 43         0.025575  IFNG, IFIH1, IFI6, OAS1, IL6, EXT1, TLR7, NLRP...
# 44         0.015345            ISG15, OAS1, USP18, OAS3, SAMHD1, STAT2
# 47         0.012788                    SCIMP, OAS1, TNF, UNC93B1, TLR3
# 45         0.012788                      IL1B, RIGI, IL12B, IL18, TLR9
# 46         0.012788                    C5AR2, CR2, FPR3, C5AR1, CMKLR1
# 48         0.010230                             IL6, TLR3, TNF, NFKBIZ
# 49         0.015345                RIGI, IFIH1, IRF7, TLR7, TLR3, TLR9
# 50         0.020460       IFNG, FAS, INHBA, CD70, YAP1, TNF, TLR3, PML
# 51         0.007673                                    IL1B, IFNG, TNF
# 52         0.007673                              PARP14, CD300LF, CD40
# 53         0.010230                               IL1B, TNF, IL6, IL18
# 54         0.017903       ISG15, CD274, IL12B, IRF4, IL6, TLR9, LGALS9
# 55         0.015345              IFI16, ACOD1, OAS1, PNPT1, MNDA, TLR3
# 56         0.015345                GBP4, IL10, IL12B, BATF, IRF4, CD40
# 57         0.020460  CCL24, CXCR5, CXCL11, CCL3, CCL3L3, CCL4, CCL8...
# 59         0.012788                  IFI16, IL31RA, PPARG, CSF1R, CSF2
# 58         0.023018  IL1B, FAS, ENG, PTGS2, KCNJ2, TLR7, PECAM1, TL...
# 62         0.015345             IFI16, ACOD1, PIM1, TRIM21, NMI, DHX58
# 60         0.015345                IL10, CR2, CD70, NFKBIZ, CD38, CD40
# 61         0.015345               IL1A, IL1B, PTGS2, IL6, SULF2, C5AR1
# 63         0.035806  IL1B, LIF, EIF2AK2, FLT1, AVPI1, TRIM5, TNF, I...
# 64         0.010230                            GREM1, IL10, IL19, EDN1
# 65         0.030691  TLR3, FCGR1A, SLAMF8, IL10, ISG15, RNF213, OAS...
# 66         0.007673                                  IRF7, OAS3, IFIH1
# 67         0.007673                                  TLR3, RIGI, IFIH1
# 68         0.015345          IL10, HDAC9, NLRP12, LRRC32, GPNMB, MERTK
# 69         0.015345             RIGI, IL12B, TRIM22, PARP9, DTX3L, PML
# 70         0.109974  MYC, IFNG, IL10, LIF, HHEX, MACC1, IL18, NOG, ...
# 71         0.010230                          IL1A, PLA2G4A, EDN1, IL1B
# 72         0.015345              IFNG, LIF, SOCS1, IL31RA, CSF1R, CSF2
# 73         0.020460  INHBA, ACOD1, ICOSLG, IL31RA, STAT2, NLRP3, MX...
# 74         0.015345                IL1A, IL1B, IFI6, TNF, BCL2L1, CSF2
# 76         0.038363  PARP14, IFNG, ENG, PARP10, CCL3, YAP1, ITGB8, ...
# 75         0.017903         PTGS2, IL6, EDN1, TNF, NOTCH3, IL18, HMOX1
# 77         0.007673                               TLR7, SCIMP, UNC93B1
# 78         0.007673                                   IL1B, TNF, PTGS2
# 79         0.012788                  IFITM1, IFITM3, PTX3, TRIM5, LY6E
# 80         0.033248  IL1A, IL1B, SEMA7A, P2RY1, SCIMP, INHBA, CCL3,...
# 81         0.020460  FZD1, IL10, TRIM14, TRIM22, TRIM21, IL6, TRIM5...
# 82         0.010230                              IFNG, TNF, IFI35, NMI
# 83         0.056266  MYC, IL10, SOCS2, IL31RA, CSF1R, PIM1, CLEC5A,...
# 84         0.007673                                     IL1B, TNF, IL6
# 85         0.007673                               ISG15, UBE2L6, HERC5
# 86         0.007673                                 TNF, SLC2A5, PTGS2
# 87         0.015345                 IL1B, IFNG, PTX3, PTGS2, EDN1, TNF
# 88         0.012788                  NFKBIZ, TLR7, UNC93B1, TLR3, TLR9
# 89         0.012788                       TLR3, IFNG, TNF, C5AR1, TLR9
# 90         0.017903     IL1B, TNFRSF13C, CD274, IL12B, CD70, IL6, TFRC
# 92         0.007673                                  IL6, IL1R2, IL1RN
# 91         0.007673                                 EXT1, IL31RA, YAP1
# 93         0.012788                      CD14, SCIMP, OAS1, NMI, TNIP3
# 94         0.010230                             C5AR1, IL1B, IFNG, TNF
# 95         0.010230                            IRF4, BATF, BATF3, CSF2
# 96         0.010230                           TLR3, RIGI, IFIT1, IFIH1
# 97         0.012788                       IL10, PNPT1, IL6, TNF, SULF2
# 98         0.012788                   ZBP1, TRIM21, NLRP3, NLRC4, GZMB
# 109        0.005115                                          NOG, IL10
# 108        0.005115                                       IFNG, LGALS9
# 107        0.005115                                        RIGI, IFIH1
# 106        0.005115                                          IFNG, TNF
# 105        0.005115                                           LTA, TNF
# 104        0.005115                                         EDN1, CSF2
# 103        0.005115                                          IL10, TNF
# 102        0.007673                                     TLR3, FAS, TNF
# 101        0.007673                                 CXCL2, IL10, CXCL8
# 100        0.007673                                 STAP1, CCL3, LRRK2
# 99         0.025575  C5AR2, CXCR5, TBXA2R, CACNA1A, P2RY1, EDN1, CD...
# 110        0.012788                    IL1B, NLRP12, TRAF1, TRAF4, TNF
# 111        0.015345        MNDA, PRF1, LGALS3BP, CLEC5A, CD300C, C5AR1
# 112        0.010230                           IRF7, RIGI, DHX58, IFIH1
# 113        0.012788                   TJP2, PTGS2, MFSD2A, IL6, PECAM1
# 114        0.015345         TNFRSF13C, FAS, CD70, TNFRSF18, TRAF1, TNF
# 115        0.028133  IL1A, MMP14, PLEKHN1, ENG, LIF, LTA, TNF, CHRN...
# 118        0.010230                                LTA, IL1B, TNF, IL6
# 119        0.010230                              IL1B, TNF, CSF2, IL18
# 116        0.069054  FZD1, MYC, IL10, HHEX, IL31RA, GDF7, INHBA, PI...
# 117        0.010230                            CCL24, CCL8, CCL3, CCL4
# 120        0.012788                    IFI16, ZBP1, MNDA, TRIM5, NLRC4
# 0          0.240741  ADORA2A, CSF1R, IL36RN, CD14, CXCL10, PTX3, FP...
# 1          0.194444  SLAMF8, IL36RN, CSF2, CSF3, FCGR1A, IL1R2, PEC...
# 2          0.148148  IL1B, MMP14, F3, CCL3, CCR1, CCL4, SYNPO2, FLT...
# 3          0.138889  IL1B, ADORA2A, INHBA, CXCL10, CCL3, IL36G, CCR...
# 4          0.120370  CSF3, CD14, IL1A, IL1B, CXCL10, IL36G, PTGS2, ...
# 5          0.111111  CSF3, IL1A, IL1B, EBI3, INHBA, F3, IL1R2, IL36...
# 6          0.101852  C5AR2, CXCL1, CXCL2, CXCL10, CCL3, CCR1, CCL8,...
# 7          0.092593  CXCL1, CXCL2, CXCL3, CXCL10, CCL3, CCL3L3, CCL...
# 8          0.129630  IL1A, IL1B, INHBA, F3, CCL3, YAP1, ITGB8, C1QT...
# 9          0.092593  CSF3, IL1B, CCL3, C1QTNF1, FLT1, TNF, PECAM1, ...
# 10         0.101852  FCGR1A, CD14, INHBA, IL1R2, CXCL10, CCR1, TNFS...
# 11         0.120370  IL1A, IL1B, ADORA2A, INHBA, E2F7, CXCL1, CCL3L...
# 13         0.064815    CXCL1, CXCL2, CXCL3, CXCL10, CCL8, CXCL8, CCL20
# 12         0.194444  NLRP12, CSF1R, IL36RN, KREMEN1, FCGR1A, CXCL10...
# 14         0.055556             CXCL10, CCL3, CCR1, CCL4, CCL3L3, CCL8
# 15         0.083333  IL1A, IL1B, ADORA2A, INHBA, CCL3, CCR1, TNF, G...
# 16         0.027778                                   IL1B, TNF, PTGS2
# 17         0.046296                       IL1B, PTX3, PTGS2, EDN1, TNF
# 18         0.027778                                     IL1B, TNF, IL6
# 19         0.037037                              MSR1, IL1B, TNF, CSF2
# 20         0.055556            CXCL1, CXCL2, CCL3, CCR1, CCL3L3, CCL20
# 21         0.027778                                     IL1B, TNF, IL6
# 22         0.037037                              FLT1, CCL3, IL6, CCR1
# 23         0.046296                   IL1B, CXCL3, CXCL10, CCL3, CXCL8
# 24         0.046296                      CCL3, NLRP12, IL6, NLRC4, TNF
# 25         0.037037                              IL1A, IL1B, EDN1, TNF
# 26         0.037037                             IL1A, IL1B, IL6, PTGS2
# 27         0.027778                                   IL1A, IL1B, EDN1
# 28         0.046296                           CD14, IL1B, F3, IL6, TNF
# 29         0.018519                                         EDN1, CSF2
# 30         0.055556                CCL3, CCR1, EDN1, TNF, CXCL8, CCL20
# 31         0.037037                         MFSD2A, PTGS2, IL6, PECAM1
# 32         0.037037                              IL1A, IL1B, TNF, CSF2
# 33         0.027778                                   EDN1, RHCG, PDK4
# 34         0.074074    MSR1, CCL3, YAP1, CCR1, ITGB8, EDN1, TNF, CXCL8
# 35         0.101852  CSF3, IL1B, CXCL10, FLT1, EDN1, IL6, IL31RA, A...
# 36         0.027778                                CXCL8, TNF, ALDH1A2
# 37         0.064815        IL1B, C1QTNF1, EDN1, FLT1, TNF, IL6, PECAM1
# 39         0.018519                                         IL1A, IL1B
# 38         0.018519                                          IL1B, TNF
# 40         0.027778                                 IL1B, TNF, ADORA2A
# 41         0.055556                 IL1A, IL1B, F3, ITGB8, FLT1, CXCL8
# 42         0.027778                                CSF1R, IL31RA, CSF2
# 43         0.037037                         C5AR2, TNF, IL36RN, NLRP12
# 44         0.027778                                   CCL8, CCL3, CCL4
# 45         0.027778                                     IL1B, TNF, IL6
# 46         0.018519                                      TNFAIP6, PTX3
# 47         0.018519                                           F3, IL1B
# 48         0.018519                                     TNFAIP6, C5AR2
# 49         0.037037                              IL6, EDN1, TNF, PTGS2
# 51         0.055556               MMP14, TGFBI, PTX3, TNF, MMP1, MMP10
# 50         0.046296                     IL1B, CCL3, NLRP12, NLRC4, TNF
# 52         0.037037                             IL6, TNF, IL31RA, CSF2
