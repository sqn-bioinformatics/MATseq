# %% [markdown]
# # Supplementary Data Visualization
#
# This notebook generates visualizations for TLR2 (Pam3Csk4) and TLR4 (LPS) HEK-Blue assay data.

# %%
import sys

sys.path.insert(0, "..")

from src.visualization import load_tlr_data, plot_tlr_hek_blue

# %%
# Load the TLR data with calculated averages and standard deviations
tlr2_df, tlr4_df, fla_pa_data = load_tlr_data()

print("TLR2 (Pam3Csk4) data:")
display(tlr2_df)

print("\nTLR4 (LPS) data:")
display(tlr4_df)

print("\nFla-PA data:")
print(fla_pa_data)
# Out:
# TLR2 (Pam3Csk4) data:
#    Concentration_ng_mL  Average
# 1                 10.0    1.740
# 2                  5.0    1.370
# 3                  2.5    1.145
# 4                  1.3    0.970
# 5                  0.6    0.885
# 6                  0.3    0.655
# 7                  0.2    0.610
# 8                  0.1    0.430
# 9                  0.0    0.320
# TLR4 (LPS) data:
#    Concentration_EU_mL  Average
# 0                20.48    1.695
# 2                10.24    1.640
# 3                 5.12    1.225
# 4                 2.56    1.025
# 5                 1.28    0.865
# 6                 0.64    0.570
# 7                 0.32    0.480
# 8                 0.16    0.360
# 9                 0.00    0.250
# Fla-PA data:
# {'tlr4': {'concentration': 16.0, 'average': 0.7}, 'tlr2': {'concentration': 20.0, 'average': 0.855}}

# %%
# Generate the combined plot with Fla-PA points
output_path = plot_tlr_hek_blue(tlr2_df, tlr4_df, fla_pa_data)
# Out:
# Plot saved as '/home/t.afanasyeva/MAT_rebase/notebooks/../results/figures/supplementary/TLR_HEK_Blue.png'
