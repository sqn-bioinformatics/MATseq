# %%
import pandas as pd
import os

# %%
stats = pd.DataFrame()
for file in os.listdir(path='/home/t.afanasyeva/output_MATseq/scripts_not_in_use/20240314'):
    df = pd.read_csv(file)
    stats[df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for file in os.listdir(path='/home/t.afanasyeva/output_MATseq/scripts_not_in_use/20240314'):
#       2     df = pd.read_csv(file)
#
# NameError: name 'os' is not defined

# %% [markdown]
# colname	type (unit)	description
# s	float (seconds)	Running time in seconds
# h:m:s	string (-)	Running time in hour, minutes, seconds format
# max_rss	float (MB)	Maximum "Resident Set Size”, this is the non-swapped physical memory a process has used.
# max_vms	float (MB)	Maximum “Virtual Memory Size”, this is the total amount of virtual memory used by the process
# max_uss	float (MB)	“Unique Set Size”, this is the memory which is unique to a process and which would be freed if the process was terminated right now.
# max_pss	float (MB)	“Proportional Set Size”, is the amount of memory shared with other processes, accounted in a way that the amount is divided evenly between the processes that share it (Linux only)
# io_in	float (MB)	the number of MB read (cumulative).
# io_out	float (MB)	the number of MB written (cumulative).
# mean_load	float (-)	CPU usage over time, divided by the total running time (first row)
# cpu_time	float(-)	CPU time summed for user and system

# %%
path = "/home/t.afanasyeva/output_MATseq/scripts_not_in_use/20240314/3samp_8_cores_benchmarks.tsv"

# %%
df1
# Out:
#                                   rule         s    h:m:s  max_rss   max_vms  \
# 0     H5C2HDSXC_105917-001-035_R2_copy    7.3085  0:00:07     6.44     14.19
# 1     H5C2HDSXC_105917-001-003_R2_copy    4.9518  0:00:04     6.71     14.19
# 2   H5C2HDSXC_105917-001-003_R2_fastqc  163.6265  0:02:43  1578.38   7425.00
# 3     H3WVTDSXC_105917-001-015_R1_copy    4.8733  0:00:04     6.88     14.19
# 4   H3WVTDSXC_105917-001-015_R1_fastqc  140.1415  0:02:20  1557.06   7360.00
# ..                                 ...       ...      ...      ...       ...
# 58             105917-001-041_umitools  588.0375  0:09:48  1046.50   1206.76
# 59        105917-001-016_featurecounts    8.2404  0:00:08   321.16   1335.95
# 60        105917-001-033_featurecounts    8.3012  0:00:08   326.98   1335.95
# 61        105917-001-041_featurecounts    8.6027  0:00:08   338.56   1335.95
# 62                                 all    0.0269  0:00:00    94.94  13738.99
#
# ...

# %%
path = "/home/t.afanasyeva/output_MATseq/scripts_not_in_use/20240314/1710359773704_benchmarks.tsv"

# %%
df = pd.read_csv(path, sep='\t')

df.s.sum()/60/60, df.max_vms.max()/1000, df.max_vms.sum()/1000, df.mean_load.sum()/1000
# Out:
# (7.503323055555555, 33.408199999999994, 999.4020399999999, 33.618)
